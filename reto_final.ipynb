# %% [markdown]
# ## Librerias y parametros iniciales

# %%
import pandas as pd
import numpy as np
from math import radians, sin, cos, sqrt, atan2
import folium
import random
import os
import json
import warnings

warnings.filterwarnings("ignore")

archivo_entrada = 'tsp_con_coordenadas.xlsx'
path_de_redes = 'redes'
path_de_resultados = 'resultados'

os.makedirs(path_de_redes, exist_ok=True)
os.makedirs(path_de_resultados, exist_ok=True)

df_tsp = pd.read_excel(archivo_entrada)

# %% [markdown]
# ## Generar redes
#
# Se generan las siguientes redes:
#
# - 10 redes con 40 nodos
# - 10 redes con 100 nodos
# - 10 redes con 150 nodos
# - 10 redes con 200 nodos

# %%
generar = False  # Cambiar a True para generar las redes si es necesario

configuraciones = {
    40: 10,
    100: 10,
    150: 10,
    200: 10
}

def generar_redes():
    numero_red = 1

    for nodos, cantidad in configuraciones.items():
        for _ in range(cantidad):
            # Crear un dataframe vacío con la misma estructura que el original
            columnas = df_tsp.columns
            red_df = pd.DataFrame(columns=columnas)

            # Lista de índices seleccionados para evitar duplicados
            nodos_seleccionados = set()

            # Seleccionar nodos aleatorios
            while len(red_df) < nodos:
                nodo = df_tsp.sample(n=1, random_state=random.randint(1, 10000))
                if nodo.index[0] not in nodos_seleccionados:
                    nodos_seleccionados.add(nodo.index[0])
                    red_df = pd.concat([red_df, nodo], ignore_index=True)

            # Guardar el DataFrame en un archivo Excel
            nombre_archivo = f"redes/{numero_red}_{nodos}.xlsx"
            red_df.to_excel(nombre_archivo, index=False)

            # Incrementar el número de red
            numero_red += 1

if generar == True:
    generar_redes()

# %% [markdown]
# ## Funciones auxiliares

# %%
def haversine_distance(coord1, coord2):
    R = 6371
    lat1, lon1 = coord1
    lat2, lon2 = coord2

    lat1_rad, lon1_rad = radians(lat1), radians(lon1)
    lat2_rad, lon2_rad = radians(lat2), radians(lon2)

    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad

    a = sin(dlat/2)**2 + cos(lat1_rad)*cos(lat2_rad)*sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

def crear_matriz_distancias(df_red):
    coordenadas = df_red[['latitud', 'longitud']].values
    n = len(coordenadas)
    matriz_distancias = np.zeros((n, n))

    for i in range(n):
        for j in range(i, n):
            distancia = haversine_distance(coordenadas[i], coordenadas[j])
            matriz_distancias[i, j] = distancia
            matriz_distancias[j, i] = distancia

    return matriz_distancias

# %% [markdown]
# ## Algoritmo genético

# %%
def inicializar_poblacion(tamano_poblacion, indices_ciudades):
    poblacion = []
    for _ in range(tamano_poblacion):
        individuo = indices_ciudades.copy()
        random.shuffle(individuo)
        poblacion.append(individuo)
    return poblacion

def calcular_aptitud(individuo, matriz_distancias):
    distancia_total = 0
    for i in range(len(individuo)):
        ciudad_origen = individuo[i]
        ciudad_destino = individuo[(i + 1) % len(individuo)]
        distancia_total += matriz_distancias[ciudad_origen][ciudad_destino]
    return distancia_total

def seleccionar_padres(poblacion, aptitudes, num_padres):
    padres_indices = np.argsort(aptitudes)[:num_padres]
    padres = [poblacion[i] for i in padres_indices]
    return padres

def cruzar_padres(padre1, padre2):
    tamano = len(padre1)
    inicio, fin = sorted(random.sample(range(tamano), 2))
    hijo = [None]*tamano
    hijo[inicio:fin+1] = padre1[inicio:fin+1]

    pointer = 0
    for i in range(tamano):
        if hijo[i] is None:
            while padre2[pointer] in hijo:
                pointer += 1
            hijo[i] = padre2[pointer]
            pointer += 1
    return hijo

def mutar_individuo(individuo, tasa_mutacion):
    for i in range(len(individuo)):
        if random.random() < tasa_mutacion:
            j = random.randint(0, len(individuo)-1)
            individuo[i], individuo[j] = individuo[j], individuo[i]
    return individuo

def algoritmo_genetico_tsp(matriz_distancias, tamano_poblacion=100, num_generaciones=100, tasa_mutacion=0.01):
    indices_ciudades = list(range(len(matriz_distancias)))
    poblacion = inicializar_poblacion(tamano_poblacion, indices_ciudades)
    mejor_distancia = float('inf')
    mejor_ruta = None

    for generacion in range(num_generaciones):
        aptitudes = [calcular_aptitud(individuo, matriz_distancias) for individuo in poblacion]
        distancia_actual = min(aptitudes)
        if distancia_actual < mejor_distancia:
            mejor_distancia = distancia_actual
            mejor_ruta = poblacion[np.argmin(aptitudes)]

        num_padres = tamano_poblacion // 2
        padres = seleccionar_padres(poblacion, aptitudes, num_padres)

        siguiente_generacion = []
        while len(siguiente_generacion) < tamano_poblacion:
            padre1, padre2 = random.sample(padres, 2)
            hijo = cruzar_padres(padre1, padre2)
            hijo = mutar_individuo(hijo, tasa_mutacion)
            siguiente_generacion.append(hijo)

        poblacion = siguiente_generacion

        if (generacion + 1) % 50 == 0:
            print(f"Generación {generacion + 1}: Mejor distancia = {mejor_distancia:.2f} km")

    return mejor_ruta, mejor_distancia

# %% [markdown]
# ## Algoritmo colonia de hormigas (ACO)

# %%
def calcular_heuristica(costos):
    num_nodos = costos.shape[0]
    heuristica = np.zeros_like(costos)
    for i in range(num_nodos):
        for j in range(num_nodos):
            if costos[i, j] > 0 and not np.isinf(costos[i, j]):
                heuristica[i, j] = 1 / costos[i, j]
            else:
                heuristica[i, j] = 0
    return heuristica

def calcular_probabilidades(feromonas, heuristica, nodo_actual, visitados, alpha, beta):
    num_nodos = len(feromonas)
    probabilidades = np.zeros(num_nodos)
    for j in range(num_nodos):
        if j not in visitados:
            probabilidades[j] = (feromonas[nodo_actual, j] ** alpha) * (heuristica[nodo_actual, j] ** beta)
    suma_probabilidades = np.sum(probabilidades)
    if suma_probabilidades == 0:
        return probabilidades
    return probabilidades / suma_probabilidades

def construir_camino(feromonas, heuristica, costos, alpha, beta):
    num_nodos = costos.shape[0]
    nodo_actual = random.randint(0, num_nodos - 1)
    camino = [nodo_actual]
    costo_total = 0
    visitados = set(camino)

    while len(camino) < num_nodos:
        probabilidades = calcular_probabilidades(feromonas, heuristica, nodo_actual, visitados, alpha, beta)
        if np.sum(probabilidades) == 0:
            nodos_no_visitados = list(set(range(num_nodos)) - visitados)
            siguiente_nodo = random.choice(nodos_no_visitados)
        else:
            siguiente_nodo = random.choices(range(num_nodos), weights=probabilidades, k=1)[0]
        costo_total += costos[nodo_actual, siguiente_nodo]
        camino.append(siguiente_nodo)
        visitados.add(siguiente_nodo)
        nodo_actual = siguiente_nodo

    costo_total += costos[camino[-1], camino[0]]
    camino.append(camino[0])

    return camino, costo_total

def actualizar_feromonas(feromonas, soluciones, rho):
    feromonas *= (1 - rho)
    for camino, costo in soluciones:
        for i in range(len(camino) - 1):
            feromonas[camino[i], camino[i + 1]] += 1 / costo

def ACO(costos, num_hormigas=500, num_iteraciones=100, alpha=1.0, beta=2.0, rho=0.5):
    num_nodos = costos.shape[0]
    mejor_camino = None
    mejor_costo = float('inf')

    feromonas = np.ones((num_nodos, num_nodos)) * 0.1
    heuristica = calcular_heuristica(costos)

    for iteracion in range(num_iteraciones):
        soluciones = []
        for _ in range(num_hormigas):
            camino, costo = construir_camino(feromonas, heuristica, costos, alpha, beta)
            soluciones.append((camino, costo))
            if costo < mejor_costo:
                mejor_camino = camino
                mejor_costo = costo

        actualizar_feromonas(feromonas, soluciones, rho)

        if (iteracion + 1) % 10 == 0:
            print(f"Iteración {iteracion+1}: Mejor costo hasta ahora = {mejor_costo:.2f} km")

    return mejor_camino, mejor_costo

# %% [markdown]
# ## Procesar las redes

# %%
def procesar_redes(archivo):
    df_red = pd.read_excel(archivo)

    matriz_distancias = crear_matriz_distancias(df_red)

    mejor_ruta_genetico, mejor_distancia_genetico = algoritmo_genetico_tsp(matriz_distancias, tamano_poblacion=100, num_generaciones=500, tasa_mutacion=0.01)
    mejor_ruta_aco, mejor_distancia_aco = ACO(matriz_distancias, num_hormigas=500, num_iteraciones=100, alpha=1.0, beta=2.0, rho=0.5)

    return mejor_ruta_genetico, mejor_distancia_genetico, mejor_ruta_aco, mejor_distancia_aco

def crear_visualizacion(df_red, mejor_ruta, nombre_archivo):
    coordenadas = df_red[['latitud', 'longitud']].values
    ruta_coordenadas = coordenadas[mejor_ruta]
    ruta_coordenadas = np.vstack([ruta_coordenadas, ruta_coordenadas[0]])

    centro_lat = np.mean(coordenadas[:, 0])
    centro_lon = np.mean(coordenadas[:, 1])
    mapa = folium.Map(location=[centro_lat, centro_lon], zoom_start=12)

    for idx, coord in enumerate(ruta_coordenadas[:-1]):
        folium.Marker(location=coord, popup=f"Parada {idx + 1}").add_to(mapa)

    folium.PolyLine(ruta_coordenadas, color="blue", weight=2.5, opacity=1).add_to(mapa)

    return mapa.save(nombre_archivo)

def procesar_archivo(archivo):
    print(f"Procesando archivo: {archivo}")
    df_red = pd.read_excel(archivo)

    path_de_resultado_base = f"{path_de_resultados}/{archivo.split('/')[-1].split('.')[0]}"
    os.makedirs(path_de_resultado_base, exist_ok=True)

    path_de_resultado_json = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}.json"
    path_de_visualizacion_genetico = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}_genetico.html"
    path_de_visualizacion_aco = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}_aco.html"

    mejor_ruta_genetico, mejor_distancia_genetico, mejor_ruta_aco, mejor_distancia_aco = procesar_redes(archivo)

    # Generar resultados en un archivo json
    with open(path_de_resultado_json, "w") as f:
        json.dump({
            "genetico": {
                "ruta": mejor_ruta_genetico,
                "distancia": mejor_distancia_genetico
            },
            "aco": {
                "ruta": mejor_ruta_aco,
                "distancia": mejor_distancia_aco
            }
        }, f)

    # Crear visualización de la mejor ruta encontrada por el algoritmo genético
    crear_visualizacion(df_red, mejor_ruta_genetico, path_de_visualizacion_genetico)
    crear_visualizacion(df_red, mejor_ruta_aco, path_de_visualizacion_aco)
    print(f"Resultados guardados en: {path_de_resultado_base}\n\n")

# Procesar cada archivo de red
paths = [f"{path_de_redes}/{archivo}" for archivo in os.listdir(path_de_redes)]
paths_sorted = sorted(paths, key=lambda x: int(x.split('/')[1].split('_')[0]))

for archivo in paths_sorted:
    procesar_archivo(archivo)
# Out:
# Procesando archivo: redes/1_40.xlsx
# Generación 50: Mejor distancia = 297.38 km
# Generación 100: Mejor distancia = 246.27 km
# Generación 150: Mejor distancia = 184.10 km
# Generación 200: Mejor distancia = 179.11 km
# Generación 250: Mejor distancia = 177.58 km
# Generación 300: Mejor distancia = 177.58 km
# Generación 350: Mejor distancia = 177.58 km
# Generación 400: Mejor distancia = 177.00 km
# Generación 450: Mejor distancia = 177.00 km
# Generación 500: Mejor distancia = 177.00 km
# Iteración 10: Mejor costo hasta ahora = 159.89 km
# Iteración 20: Mejor costo hasta ahora = 157.17 km
# Iteración 30: Mejor costo hasta ahora = 156.58 km
# Iteración 40: Mejor costo hasta ahora = 156.58 km
# Iteración 50: Mejor costo hasta ahora = 156.41 km
# Iteración 60: Mejor costo hasta ahora = 156.41 km
# Iteración 70: Mejor costo hasta ahora = 156.41 km
# Iteración 80: Mejor costo hasta ahora = 156.41 km
# Iteración 90: Mejor costo hasta ahora = 156.41 km
# Iteración 100: Mejor costo hasta ahora = 156.41 km
# Resultados guardados en: resultados/1_40
#
#
# Procesando archivo: redes/2_40.xlsx
# Generación 50: Mejor distancia = 290.42 km
# Generación 100: Mejor distancia = 272.21 km
# Generación 150: Mejor distancia = 266.67 km
# Generación 200: Mejor distancia = 210.20 km
# Generación 250: Mejor distancia = 189.85 km
# Generación 300: Mejor distancia = 188.49 km
# Generación 350: Mejor distancia = 186.72 km
# Generación 400: Mejor distancia = 185.06 km
# Generación 450: Mejor distancia = 184.64 km
# Generación 500: Mejor distancia = 184.64 km
# Iteración 10: Mejor costo hasta ahora = 155.46 km
# Iteración 20: Mejor costo hasta ahora = 151.82 km
# Iteración 30: Mejor costo hasta ahora = 151.82 km
# Iteración 40: Mejor costo hasta ahora = 151.82 km
# Iteración 50: Mejor costo hasta ahora = 151.82 km
# Iteración 60: Mejor costo hasta ahora = 151.82 km
# Iteración 70: Mejor costo hasta ahora = 151.82 km
# Iteración 80: Mejor costo hasta ahora = 151.82 km
# Iteración 90: Mejor costo hasta ahora = 151.82 km
# Iteración 100: Mejor costo hasta ahora = 151.82 km
# Resultados guardados en: resultados/2_40
#
#
# Procesando archivo: redes/3_40.xlsx
# Generación 50: Mejor distancia = 224.66 km
# Generación 100: Mejor distancia = 219.37 km
# Generación 150: Mejor distancia = 217.48 km
# Generación 200: Mejor distancia = 204.81 km
# Generación 250: Mejor distancia = 161.80 km
# Generación 300: Mejor distancia = 131.10 km
# Generación 350: Mejor distancia = 119.70 km
# Generación 400: Mejor distancia = 119.70 km
# Generación 450: Mejor distancia = 119.70 km
# Generación 500: Mejor distancia = 119.70 km
# Iteración 10: Mejor costo hasta ahora = 105.35 km
# Iteración 20: Mejor costo hasta ahora = 105.35 km
# Iteración 30: Mejor costo hasta ahora = 104.69 km
# Iteración 40: Mejor costo hasta ahora = 104.69 km
# Iteración 50: Mejor costo hasta ahora = 104.69 km
# Iteración 60: Mejor costo hasta ahora = 104.69 km
# Iteración 70: Mejor costo hasta ahora = 104.69 km
# Iteración 80: Mejor costo hasta ahora = 104.69 km
# Iteración 90: Mejor costo hasta ahora = 104.69 km
# Iteración 100: Mejor costo hasta ahora = 104.69 km
# Resultados guardados en: resultados/3_40
#
#
# Procesando archivo: redes/4_40.xlsx
# Generación 50: Mejor distancia = 187.06 km
# Generación 100: Mejor distancia = 187.06 km
# Generación 150: Mejor distancia = 145.14 km
# Generación 200: Mejor distancia = 135.44 km
# Generación 250: Mejor distancia = 133.54 km
# Generación 300: Mejor distancia = 130.59 km
# Generación 350: Mejor distancia = 129.17 km
# Generación 400: Mejor distancia = 127.84 km
# Generación 450: Mejor distancia = 127.84 km
# Generación 500: Mejor distancia = 127.84 km
# Iteración 10: Mejor costo hasta ahora = 105.39 km
# Iteración 20: Mejor costo hasta ahora = 102.07 km
# Iteración 30: Mejor costo hasta ahora = 101.77 km
# Iteración 40: Mejor costo hasta ahora = 101.77 km
# Iteración 50: Mejor costo hasta ahora = 101.27 km
# Iteración 60: Mejor costo hasta ahora = 101.27 km
# Iteración 70: Mejor costo hasta ahora = 101.27 km
# Iteración 80: Mejor costo hasta ahora = 101.27 km
# Iteración 90: Mejor costo hasta ahora = 101.27 km
# Iteración 100: Mejor costo hasta ahora = 101.27 km
# Resultados guardados en: resultados/4_40
#
#
# Procesando archivo: redes/5_40.xlsx
# Generación 50: Mejor distancia = 257.94 km
# Generación 100: Mejor distancia = 221.38 km
# Generación 150: Mejor distancia = 149.83 km
# Generación 200: Mejor distancia = 126.08 km
# Generación 250: Mejor distancia = 125.77 km
# Generación 300: Mejor distancia = 125.77 km
# Generación 350: Mejor distancia = 125.77 km
# Generación 400: Mejor distancia = 125.77 km
# Generación 450: Mejor distancia = 125.77 km
# Generación 500: Mejor distancia = 125.77 km
# Iteración 10: Mejor costo hasta ahora = 114.06 km
# Iteración 20: Mejor costo hasta ahora = 111.70 km
# Iteración 30: Mejor costo hasta ahora = 111.70 km
# Iteración 40: Mejor costo hasta ahora = 111.70 km
# Iteración 50: Mejor costo hasta ahora = 111.70 km
# Iteración 60: Mejor costo hasta ahora = 111.70 km
# Iteración 70: Mejor costo hasta ahora = 111.70 km
# Iteración 80: Mejor costo hasta ahora = 111.70 km
# Iteración 90: Mejor costo hasta ahora = 111.70 km
# Iteración 100: Mejor costo hasta ahora = 111.70 km
# Resultados guardados en: resultados/5_40
#
#
# Procesando archivo: redes/6_40.xlsx
# Generación 50: Mejor distancia = 224.86 km
# Generación 100: Mejor distancia = 155.73 km
# Generación 150: Mejor distancia = 141.73 km
# Generación 200: Mejor distancia = 138.30 km
# Generación 250: Mejor distancia = 138.30 km
# Generación 300: Mejor distancia = 138.18 km
# Generación 350: Mejor distancia = 138.10 km
# Generación 400: Mejor distancia = 138.10 km
# Generación 450: Mejor distancia = 138.10 km
# Generación 500: Mejor distancia = 138.10 km
# Iteración 10: Mejor costo hasta ahora = 120.69 km
# Iteración 20: Mejor costo hasta ahora = 118.71 km
# Iteración 30: Mejor costo hasta ahora = 118.18 km
# Iteración 40: Mejor costo hasta ahora = 117.94 km
# Iteración 50: Mejor costo hasta ahora = 117.13 km
# Iteración 60: Mejor costo hasta ahora = 117.13 km
# Iteración 70: Mejor costo hasta ahora = 116.89 km
# Iteración 80: Mejor costo hasta ahora = 116.89 km
# Iteración 90: Mejor costo hasta ahora = 116.89 km
# Iteración 100: Mejor costo hasta ahora = 116.89 km
# Resultados guardados en: resultados/6_40
#
#
# Procesando archivo: redes/7_40.xlsx
# Generación 50: Mejor distancia = 217.12 km
# Generación 100: Mejor distancia = 156.86 km
# Generación 150: Mejor distancia = 139.50 km
# Generación 200: Mejor distancia = 134.33 km
# Generación 250: Mejor distancia = 133.80 km
# Generación 300: Mejor distancia = 133.80 km
# Generación 350: Mejor distancia = 133.80 km
# Generación 400: Mejor distancia = 133.80 km
# Generación 450: Mejor distancia = 133.80 km
# Generación 500: Mejor distancia = 133.80 km
# Iteración 10: Mejor costo hasta ahora = 113.47 km
# Iteración 20: Mejor costo hasta ahora = 111.23 km
# Iteración 30: Mejor costo hasta ahora = 110.88 km
# Iteración 40: Mejor costo hasta ahora = 110.88 km
# Iteración 50: Mejor costo hasta ahora = 110.88 km
# Iteración 60: Mejor costo hasta ahora = 110.88 km
# Iteración 70: Mejor costo hasta ahora = 110.88 km
# Iteración 80: Mejor costo hasta ahora = 110.88 km
# Iteración 90: Mejor costo hasta ahora = 110.88 km
# Iteración 100: Mejor costo hasta ahora = 110.88 km
# Resultados guardados en: resultados/7_40
#
#
# Procesando archivo: redes/8_40.xlsx
# Generación 50: Mejor distancia = 287.85 km
# Generación 100: Mejor distancia = 218.74 km
# Generación 150: Mejor distancia = 191.93 km
# Generación 200: Mejor distancia = 173.65 km
# Generación 250: Mejor distancia = 159.68 km
# Generación 300: Mejor distancia = 153.93 km
# Generación 350: Mejor distancia = 153.93 km
# Generación 400: Mejor distancia = 152.08 km
# Generación 450: Mejor distancia = 150.06 km
# Generación 500: Mejor distancia = 144.56 km
# Iteración 10: Mejor costo hasta ahora = 133.87 km
# Iteración 20: Mejor costo hasta ahora = 130.30 km
# Iteración 30: Mejor costo hasta ahora = 130.30 km
# Iteración 40: Mejor costo hasta ahora = 130.30 km
# Iteración 50: Mejor costo hasta ahora = 130.30 km
# Iteración 60: Mejor costo hasta ahora = 130.30 km
# Iteración 70: Mejor costo hasta ahora = 130.30 km
# Iteración 80: Mejor costo hasta ahora = 130.30 km
# Iteración 90: Mejor costo hasta ahora = 130.30 km
# Iteración 100: Mejor costo hasta ahora = 130.30 km
# Resultados guardados en: resultados/8_40
#
#
# Procesando archivo: redes/9_40.xlsx
# Generación 50: Mejor distancia = 290.04 km
# Generación 100: Mejor distancia = 175.53 km
# Generación 150: Mejor distancia = 171.78 km
# Generación 200: Mejor distancia = 167.07 km
# Generación 250: Mejor distancia = 167.07 km
# Generación 300: Mejor distancia = 167.07 km
# Generación 350: Mejor distancia = 167.07 km
# Generación 400: Mejor distancia = 167.07 km
# Generación 450: Mejor distancia = 167.07 km
# Generación 500: Mejor distancia = 167.07 km
# Iteración 10: Mejor costo hasta ahora = 152.58 km
# Iteración 20: Mejor costo hasta ahora = 146.84 km
# Iteración 30: Mejor costo hasta ahora = 146.84 km
# Iteración 40: Mejor costo hasta ahora = 146.84 km
# Iteración 50: Mejor costo hasta ahora = 146.84 km
# Iteración 60: Mejor costo hasta ahora = 146.84 km
# Iteración 70: Mejor costo hasta ahora = 146.84 km
# Iteración 80: Mejor costo hasta ahora = 146.84 km
# Iteración 90: Mejor costo hasta ahora = 146.84 km
# Iteración 100: Mejor costo hasta ahora = 146.84 km
# Resultados guardados en: resultados/9_40
#
#
# Procesando archivo: redes/10_40.xlsx
# Generación 50: Mejor distancia = 266.09 km
# Generación 100: Mejor distancia = 266.09 km
# Generación 150: Mejor distancia = 221.11 km
# Generación 200: Mejor distancia = 192.77 km
# Generación 250: Mejor distancia = 177.60 km
# Generación 300: Mejor distancia = 172.94 km
# Generación 350: Mejor distancia = 171.92 km
# Generación 400: Mejor distancia = 171.92 km
# Generación 450: Mejor distancia = 171.92 km
# Generación 500: Mejor distancia = 171.92 km
# Iteración 10: Mejor costo hasta ahora = 153.18 km
# Iteración 20: Mejor costo hasta ahora = 153.18 km
# Iteración 30: Mejor costo hasta ahora = 153.18 km
# Iteración 40: Mejor costo hasta ahora = 153.18 km
# Iteración 50: Mejor costo hasta ahora = 153.18 km
# Iteración 60: Mejor costo hasta ahora = 152.92 km
# Iteración 70: Mejor costo hasta ahora = 152.92 km
# Iteración 80: Mejor costo hasta ahora = 152.92 km
# Iteración 90: Mejor costo hasta ahora = 152.92 km
# Iteración 100: Mejor costo hasta ahora = 152.92 km
# Resultados guardados en: resultados/10_40
#
#
# Procesando archivo: redes/11_100.xlsx
# Generación 50: Mejor distancia = 829.95 km
# Generación 100: Mejor distancia = 780.50 km
# Generación 150: Mejor distancia = 774.98 km
# Generación 200: Mejor distancia = 748.53 km
# Generación 250: Mejor distancia = 748.53 km
# Generación 300: Mejor distancia = 745.45 km
# Generación 350: Mejor distancia = 730.13 km
# Generación 400: Mejor distancia = 723.25 km
# Generación 450: Mejor distancia = 723.25 km
# Generación 500: Mejor distancia = 723.25 km
# Iteración 10: Mejor costo hasta ahora = 222.22 km
# Iteración 20: Mejor costo hasta ahora = 220.31 km
# Iteración 30: Mejor costo hasta ahora = 220.31 km
# Iteración 40: Mejor costo hasta ahora = 219.85 km
# Iteración 50: Mejor costo hasta ahora = 217.23 km
# Iteración 60: Mejor costo hasta ahora = 217.23 km
# Iteración 70: Mejor costo hasta ahora = 214.90 km
# Iteración 80: Mejor costo hasta ahora = 214.90 km
# Iteración 90: Mejor costo hasta ahora = 214.90 km
# Iteración 100: Mejor costo hasta ahora = 214.90 km
# Resultados guardados en: resultados/11_100
#
#
# Procesando archivo: redes/12_100.xlsx
# Generación 50: Mejor distancia = 743.05 km
# Generación 100: Mejor distancia = 652.09 km
# Generación 150: Mejor distancia = 652.09 km
# Generación 200: Mejor distancia = 652.09 km
# Generación 250: Mejor distancia = 652.09 km
# Generación 300: Mejor distancia = 652.09 km
# Generación 350: Mejor distancia = 652.09 km
# Generación 400: Mejor distancia = 652.09 km
# Generación 450: Mejor distancia = 652.09 km
# Generación 500: Mejor distancia = 652.09 km
# Iteración 10: Mejor costo hasta ahora = 186.12 km
# Iteración 20: Mejor costo hasta ahora = 181.20 km
# Iteración 30: Mejor costo hasta ahora = 176.71 km
# Iteración 40: Mejor costo hasta ahora = 175.72 km
# Iteración 50: Mejor costo hasta ahora = 175.72 km
# Iteración 60: Mejor costo hasta ahora = 173.88 km
# Iteración 70: Mejor costo hasta ahora = 173.88 km
# Iteración 80: Mejor costo hasta ahora = 172.04 km
# Iteración 90: Mejor costo hasta ahora = 172.04 km
# Iteración 100: Mejor costo hasta ahora = 172.04 km
# Resultados guardados en: resultados/12_100
#
#
# Procesando archivo: redes/13_100.xlsx
# Generación 50: Mejor distancia = 755.18 km
# Generación 100: Mejor distancia = 751.13 km
# Generación 150: Mejor distancia = 751.13 km
# Generación 200: Mejor distancia = 739.35 km
# Generación 250: Mejor distancia = 724.27 km
# Generación 300: Mejor distancia = 720.16 km
# Generación 350: Mejor distancia = 708.95 km
# Generación 400: Mejor distancia = 708.95 km
# Generación 450: Mejor distancia = 708.95 km
# Generación 500: Mejor distancia = 708.95 km
# Iteración 10: Mejor costo hasta ahora = 180.86 km
# Iteración 20: Mejor costo hasta ahora = 178.51 km
# Iteración 30: Mejor costo hasta ahora = 173.17 km
# Iteración 40: Mejor costo hasta ahora = 173.17 km
# Iteración 50: Mejor costo hasta ahora = 173.17 km
# Iteración 60: Mejor costo hasta ahora = 173.17 km
# Iteración 70: Mejor costo hasta ahora = 173.17 km
# Iteración 80: Mejor costo hasta ahora = 173.11 km
# Iteración 90: Mejor costo hasta ahora = 173.11 km
# Iteración 100: Mejor costo hasta ahora = 173.11 km
# Resultados guardados en: resultados/13_100
#
#
# Procesando archivo: redes/14_100.xlsx
# Generación 50: Mejor distancia = 745.04 km
# Generación 100: Mejor distancia = 736.02 km
# Generación 150: Mejor distancia = 710.35 km
# Generación 200: Mejor distancia = 710.35 km
# Generación 250: Mejor distancia = 710.35 km
# Generación 300: Mejor distancia = 641.70 km
# Generación 350: Mejor distancia = 641.70 km
# Generación 400: Mejor distancia = 641.70 km
# Generación 450: Mejor distancia = 641.70 km
# Generación 500: Mejor distancia = 641.70 km
# Iteración 10: Mejor costo hasta ahora = 180.15 km
# Iteración 20: Mejor costo hasta ahora = 172.10 km
# Iteración 30: Mejor costo hasta ahora = 168.75 km
# Iteración 40: Mejor costo hasta ahora = 167.62 km
# Iteración 50: Mejor costo hasta ahora = 163.22 km
# Iteración 60: Mejor costo hasta ahora = 163.22 km
# Iteración 70: Mejor costo hasta ahora = 163.22 km
# Iteración 80: Mejor costo hasta ahora = 163.22 km
# Iteración 90: Mejor costo hasta ahora = 163.22 km
# Iteración 100: Mejor costo hasta ahora = 163.22 km
# Resultados guardados en: resultados/14_100
#
#
# Procesando archivo: redes/15_100.xlsx
# Generación 50: Mejor distancia = 873.11 km
# Generación 100: Mejor distancia = 830.62 km
# Generación 150: Mejor distancia = 827.62 km
# Generación 200: Mejor distancia = 827.62 km
# Generación 250: Mejor distancia = 827.62 km
# Generación 300: Mejor distancia = 827.62 km
# Generación 350: Mejor distancia = 827.62 km
# Generación 400: Mejor distancia = 818.59 km
# Generación 450: Mejor distancia = 818.59 km
# Generación 500: Mejor distancia = 801.47 km
# Iteración 10: Mejor costo hasta ahora = 269.41 km
# Iteración 20: Mejor costo hasta ahora = 266.54 km
# Iteración 30: Mejor costo hasta ahora = 266.54 km
# Iteración 40: Mejor costo hasta ahora = 264.17 km
# Iteración 50: Mejor costo hasta ahora = 262.37 km
# Iteración 60: Mejor costo hasta ahora = 262.37 km
# Iteración 70: Mejor costo hasta ahora = 262.37 km
# Iteración 80: Mejor costo hasta ahora = 262.37 km
# Iteración 90: Mejor costo hasta ahora = 262.37 km
# Iteración 100: Mejor costo hasta ahora = 262.37 km
# Resultados guardados en: resultados/15_100
#
#
# Procesando archivo: redes/16_100.xlsx
# Generación 50: Mejor distancia = 817.90 km
# Generación 100: Mejor distancia = 740.76 km
# Generación 150: Mejor distancia = 730.43 km
# Generación 200: Mejor distancia = 730.43 km
# Generación 250: Mejor distancia = 730.43 km
# Generación 300: Mejor distancia = 730.43 km
# Generación 350: Mejor distancia = 730.43 km
# Generación 400: Mejor distancia = 727.68 km
# Generación 450: Mejor distancia = 727.68 km
# Generación 500: Mejor distancia = 727.68 km
# Iteración 10: Mejor costo hasta ahora = 212.40 km
# Iteración 20: Mejor costo hasta ahora = 207.19 km
# Iteración 30: Mejor costo hasta ahora = 203.58 km
# Iteración 40: Mejor costo hasta ahora = 202.60 km
# Iteración 50: Mejor costo hasta ahora = 202.38 km
# Iteración 60: Mejor costo hasta ahora = 202.38 km
# Iteración 70: Mejor costo hasta ahora = 201.74 km
# Iteración 80: Mejor costo hasta ahora = 201.74 km
# Iteración 90: Mejor costo hasta ahora = 201.74 km
# Iteración 100: Mejor costo hasta ahora = 201.53 km
# Resultados guardados en: resultados/16_100
#
#
# Procesando archivo: redes/17_100.xlsx
# Generación 50: Mejor distancia = 755.33 km
# Generación 100: Mejor distancia = 746.83 km
# Generación 150: Mejor distancia = 726.72 km
# Generación 200: Mejor distancia = 726.72 km
# Generación 250: Mejor distancia = 724.18 km
# Generación 300: Mejor distancia = 707.05 km
# Generación 350: Mejor distancia = 707.05 km
# Generación 400: Mejor distancia = 707.05 km
# Generación 450: Mejor distancia = 707.05 km
# Generación 500: Mejor distancia = 707.05 km
# Iteración 10: Mejor costo hasta ahora = 205.51 km
# Iteración 20: Mejor costo hasta ahora = 205.51 km
# Iteración 30: Mejor costo hasta ahora = 205.51 km
# Iteración 40: Mejor costo hasta ahora = 204.02 km
# Iteración 50: Mejor costo hasta ahora = 204.02 km
# Iteración 60: Mejor costo hasta ahora = 204.02 km
# Iteración 70: Mejor costo hasta ahora = 201.43 km
# Iteración 80: Mejor costo hasta ahora = 200.48 km
# Iteración 90: Mejor costo hasta ahora = 200.48 km
# Iteración 100: Mejor costo hasta ahora = 200.48 km
# Resultados guardados en: resultados/17_100
#
#
# Procesando archivo: redes/18_100.xlsx
# Generación 50: Mejor distancia = 837.86 km
# Generación 100: Mejor distancia = 764.39 km
# Generación 150: Mejor distancia = 764.39 km
# Generación 200: Mejor distancia = 764.39 km
# Generación 250: Mejor distancia = 764.39 km
# Generación 300: Mejor distancia = 764.39 km
# Generación 350: Mejor distancia = 764.39 km
# Generación 400: Mejor distancia = 764.39 km
# Generación 450: Mejor distancia = 764.39 km
# Generación 500: Mejor distancia = 764.39 km
# Iteración 10: Mejor costo hasta ahora = 220.13 km
# Iteración 20: Mejor costo hasta ahora = 211.76 km
# Iteración 30: Mejor costo hasta ahora = 206.96 km
# Iteración 40: Mejor costo hasta ahora = 206.96 km
# Iteración 50: Mejor costo hasta ahora = 206.96 km
# Iteración 60: Mejor costo hasta ahora = 203.61 km
# Iteración 70: Mejor costo hasta ahora = 203.41 km
# Iteración 80: Mejor costo hasta ahora = 203.41 km
# Iteración 90: Mejor costo hasta ahora = 202.71 km
# Iteración 100: Mejor costo hasta ahora = 202.71 km
# Resultados guardados en: resultados/18_100
#
#
# Procesando archivo: redes/19_100.xlsx
# Generación 50: Mejor distancia = 774.24 km
# Generación 100: Mejor distancia = 726.28 km
# Generación 150: Mejor distancia = 709.45 km
# Generación 200: Mejor distancia = 709.45 km
# Generación 250: Mejor distancia = 709.45 km
# Generación 300: Mejor distancia = 709.45 km
# Generación 350: Mejor distancia = 709.45 km
# Generación 400: Mejor distancia = 709.45 km
# Generación 450: Mejor distancia = 709.45 km
# Generación 500: Mejor distancia = 700.65 km
# Iteración 10: Mejor costo hasta ahora = 203.64 km
# Iteración 20: Mejor costo hasta ahora = 196.87 km
# Iteración 30: Mejor costo hasta ahora = 196.87 km
# Iteración 40: Mejor costo hasta ahora = 196.39 km
# Iteración 50: Mejor costo hasta ahora = 194.66 km
# Iteración 60: Mejor costo hasta ahora = 194.66 km
# Iteración 70: Mejor costo hasta ahora = 190.69 km
# Iteración 80: Mejor costo hasta ahora = 190.69 km
# Iteración 90: Mejor costo hasta ahora = 190.69 km
# Iteración 100: Mejor costo hasta ahora = 190.69 km
# Resultados guardados en: resultados/19_100
#
#
# Procesando archivo: redes/20_100.xlsx
# Generación 50: Mejor distancia = 775.29 km
# Generación 100: Mejor distancia = 768.53 km
# Generación 150: Mejor distancia = 717.45 km
# Generación 200: Mejor distancia = 717.45 km
# Generación 250: Mejor distancia = 717.45 km
# Generación 300: Mejor distancia = 717.45 km
# Generación 350: Mejor distancia = 717.45 km
# Generación 400: Mejor distancia = 717.45 km
# Generación 450: Mejor distancia = 717.45 km
# Generación 500: Mejor distancia = 717.45 km
# Iteración 10: Mejor costo hasta ahora = 222.69 km
# Iteración 20: Mejor costo hasta ahora = 218.34 km
# Iteración 30: Mejor costo hasta ahora = 216.10 km
# Iteración 40: Mejor costo hasta ahora = 215.37 km
# Iteración 50: Mejor costo hasta ahora = 214.13 km
# Iteración 60: Mejor costo hasta ahora = 214.13 km
# Iteración 70: Mejor costo hasta ahora = 214.13 km
# Iteración 80: Mejor costo hasta ahora = 214.13 km
# Iteración 90: Mejor costo hasta ahora = 214.13 km
# Iteración 100: Mejor costo hasta ahora = 214.13 km
# Resultados guardados en: resultados/20_100
#
#
# Procesando archivo: redes/21_150.xlsx
# Generación 50: Mejor distancia = 1273.37 km
# Generación 100: Mejor distancia = 1232.37 km
# Generación 150: Mejor distancia = 1232.37 km
# Generación 200: Mejor distancia = 1232.37 km
# Generación 250: Mejor distancia = 1232.37 km
# Generación 300: Mejor distancia = 1197.59 km
# Generación 350: Mejor distancia = 1197.59 km
# Generación 400: Mejor distancia = 1197.59 km
# Generación 450: Mejor distancia = 1197.59 km
# Generación 500: Mejor distancia = 1197.59 km
# Iteración 10: Mejor costo hasta ahora = 298.28 km
# Iteración 20: Mejor costo hasta ahora = 285.83 km
# Iteración 30: Mejor costo hasta ahora = 284.08 km
# Iteración 40: Mejor costo hasta ahora = 284.08 km
# Iteración 50: Mejor costo hasta ahora = 279.94 km
# Iteración 60: Mejor costo hasta ahora = 279.94 km
# Iteración 70: Mejor costo hasta ahora = 279.94 km
# Iteración 80: Mejor costo hasta ahora = 278.59 km
# Iteración 90: Mejor costo hasta ahora = 278.59 km
# Iteración 100: Mejor costo hasta ahora = 278.59 km
# Resultados guardados en: resultados/21_150
#
#
# Procesando archivo: redes/22_150.xlsx
# Generación 50: Mejor distancia = 1277.36 km
# Generación 100: Mejor distancia = 1277.36 km
# Generación 150: Mejor distancia = 1244.92 km
# Generación 200: Mejor distancia = 1244.92 km
# Generación 250: Mejor distancia = 1244.92 km
# Generación 300: Mejor distancia = 1221.99 km
# Generación 350: Mejor distancia = 1221.99 km
# Generación 400: Mejor distancia = 1221.99 km
# Generación 450: Mejor distancia = 1221.99 km
# Generación 500: Mejor distancia = 1221.99 km
# Iteración 10: Mejor costo hasta ahora = 286.96 km
# Iteración 20: Mejor costo hasta ahora = 277.58 km
# Iteración 30: Mejor costo hasta ahora = 277.58 km
# Iteración 40: Mejor costo hasta ahora = 277.58 km
# Iteración 50: Mejor costo hasta ahora = 277.58 km
# Iteración 60: Mejor costo hasta ahora = 277.58 km
# Iteración 70: Mejor costo hasta ahora = 277.58 km
# Iteración 80: Mejor costo hasta ahora = 277.58 km
# Iteración 90: Mejor costo hasta ahora = 275.48 km
# Iteración 100: Mejor costo hasta ahora = 275.48 km
# Resultados guardados en: resultados/22_150
#
#
# Procesando archivo: redes/23_150.xlsx
# Generación 50: Mejor distancia = 1216.19 km
# Generación 100: Mejor distancia = 1193.01 km
# Generación 150: Mejor distancia = 1180.17 km
# Generación 200: Mejor distancia = 1180.17 km
# Generación 250: Mejor distancia = 1149.16 km
# Generación 300: Mejor distancia = 1149.16 km
# Generación 350: Mejor distancia = 1149.16 km
# Generación 400: Mejor distancia = 1149.16 km
# Generación 450: Mejor distancia = 1149.16 km
# Generación 500: Mejor distancia = 1149.16 km
# Iteración 10: Mejor costo hasta ahora = 271.81 km
# Iteración 20: Mejor costo hasta ahora = 262.88 km
# Iteración 30: Mejor costo hasta ahora = 262.88 km
# Iteración 40: Mejor costo hasta ahora = 261.30 km
# Iteración 50: Mejor costo hasta ahora = 261.30 km
# Iteración 60: Mejor costo hasta ahora = 261.30 km
# Iteración 70: Mejor costo hasta ahora = 261.30 km
# Iteración 80: Mejor costo hasta ahora = 261.30 km
# Iteración 90: Mejor costo hasta ahora = 261.30 km
# Iteración 100: Mejor costo hasta ahora = 255.76 km
# Resultados guardados en: resultados/23_150
#
#
# Procesando archivo: redes/24_150.xlsx
# Generación 50: Mejor distancia = 1383.80 km
# Generación 100: Mejor distancia = 1383.80 km
# Generación 150: Mejor distancia = 1352.82 km
# Generación 200: Mejor distancia = 1347.46 km
# Generación 250: Mejor distancia = 1347.46 km
# Generación 300: Mejor distancia = 1285.35 km
# Generación 350: Mejor distancia = 1285.35 km
# Generación 400: Mejor distancia = 1285.35 km
# Generación 450: Mejor distancia = 1285.35 km
# Generación 500: Mejor distancia = 1285.35 km
# Iteración 10: Mejor costo hasta ahora = 300.24 km
# Iteración 20: Mejor costo hasta ahora = 296.28 km
# Iteración 30: Mejor costo hasta ahora = 289.41 km
# Iteración 40: Mejor costo hasta ahora = 289.41 km
# Iteración 50: Mejor costo hasta ahora = 289.41 km
# Iteración 60: Mejor costo hasta ahora = 285.64 km
# Iteración 70: Mejor costo hasta ahora = 285.64 km
# Iteración 80: Mejor costo hasta ahora = 285.64 km
# Iteración 90: Mejor costo hasta ahora = 285.64 km
# Iteración 100: Mejor costo hasta ahora = 285.64 km
# Resultados guardados en: resultados/24_150
#
#
# Procesando archivo: redes/25_150.xlsx
# Generación 50: Mejor distancia = 1306.41 km
# Generación 100: Mejor distancia = 1245.43 km
# Generación 150: Mejor distancia = 1245.43 km
# Generación 200: Mejor distancia = 1245.43 km
# Generación 250: Mejor distancia = 1245.43 km
# Generación 300: Mejor distancia = 1245.43 km
# Generación 350: Mejor distancia = 1245.43 km
# Generación 400: Mejor distancia = 1245.43 km
# Generación 450: Mejor distancia = 1245.43 km
# Generación 500: Mejor distancia = 1245.43 km
# Iteración 10: Mejor costo hasta ahora = 268.64 km
# Iteración 20: Mejor costo hasta ahora = 262.41 km
# Iteración 30: Mejor costo hasta ahora = 262.41 km
# Iteración 40: Mejor costo hasta ahora = 259.41 km
# Iteración 50: Mejor costo hasta ahora = 254.03 km
# Iteración 60: Mejor costo hasta ahora = 254.03 km
# Iteración 70: Mejor costo hasta ahora = 254.03 km
# Iteración 80: Mejor costo hasta ahora = 254.03 km
# Iteración 90: Mejor costo hasta ahora = 254.03 km
# Iteración 100: Mejor costo hasta ahora = 254.03 km
# Resultados guardados en: resultados/25_150
#
#
# Procesando archivo: redes/26_150.xlsx
# Generación 50: Mejor distancia = 1223.25 km
# Generación 100: Mejor distancia = 1160.33 km
# Generación 150: Mejor distancia = 1112.32 km
# Generación 200: Mejor distancia = 1112.32 km
# Generación 250: Mejor distancia = 1112.32 km
# Generación 300: Mejor distancia = 1112.32 km
# Generación 350: Mejor distancia = 1112.32 km
# Generación 400: Mejor distancia = 1112.32 km
# Generación 450: Mejor distancia = 1112.32 km
# Generación 500: Mejor distancia = 1112.32 km
# Iteración 10: Mejor costo hasta ahora = 255.04 km
# Iteración 20: Mejor costo hasta ahora = 248.28 km
# Iteración 30: Mejor costo hasta ahora = 245.88 km
# Iteración 40: Mejor costo hasta ahora = 245.88 km
# Iteración 50: Mejor costo hasta ahora = 244.28 km
# Iteración 60: Mejor costo hasta ahora = 244.28 km
# Iteración 70: Mejor costo hasta ahora = 244.28 km
# Iteración 80: Mejor costo hasta ahora = 244.28 km
# Iteración 90: Mejor costo hasta ahora = 244.28 km
# Iteración 100: Mejor costo hasta ahora = 244.28 km
# Resultados guardados en: resultados/26_150
#
#
# Procesando archivo: redes/27_150.xlsx
# Generación 50: Mejor distancia = 1235.99 km
# Generación 100: Mejor distancia = 1228.38 km
# Generación 150: Mejor distancia = 1228.38 km
# Generación 200: Mejor distancia = 1228.38 km
# Generación 250: Mejor distancia = 1228.38 km
# Generación 300: Mejor distancia = 1180.78 km
# Generación 350: Mejor distancia = 1093.15 km
# Generación 400: Mejor distancia = 1093.15 km
# Generación 450: Mejor distancia = 1093.15 km
# Generación 500: Mejor distancia = 1093.15 km
# Iteración 10: Mejor costo hasta ahora = 279.43 km
# Iteración 20: Mejor costo hasta ahora = 259.82 km
# Iteración 30: Mejor costo hasta ahora = 259.82 km
# Iteración 40: Mejor costo hasta ahora = 259.82 km
# Iteración 50: Mejor costo hasta ahora = 259.82 km
# Iteración 60: Mejor costo hasta ahora = 259.05 km
# Iteración 70: Mejor costo hasta ahora = 259.05 km
# Iteración 80: Mejor costo hasta ahora = 259.05 km
# Iteración 90: Mejor costo hasta ahora = 257.31 km
# Iteración 100: Mejor costo hasta ahora = 257.31 km
# Resultados guardados en: resultados/27_150
#
#
# Procesando archivo: redes/28_150.xlsx
# Generación 50: Mejor distancia = 1299.35 km
# Generación 100: Mejor distancia = 1259.70 km
# Generación 150: Mejor distancia = 1231.03 km
# Generación 200: Mejor distancia = 1231.03 km
# Generación 250: Mejor distancia = 1231.03 km
# Generación 300: Mejor distancia = 1231.03 km
# Generación 350: Mejor distancia = 1215.04 km
# Generación 400: Mejor distancia = 1213.18 km
# Generación 450: Mejor distancia = 1192.58 km
# Generación 500: Mejor distancia = 1137.72 km
# Iteración 10: Mejor costo hasta ahora = 304.60 km
# Iteración 20: Mejor costo hasta ahora = 288.25 km
# Iteración 30: Mejor costo hasta ahora = 288.25 km
# Iteración 40: Mejor costo hasta ahora = 288.25 km
# Iteración 50: Mejor costo hasta ahora = 288.25 km
# Iteración 60: Mejor costo hasta ahora = 288.25 km
# Iteración 70: Mejor costo hasta ahora = 288.25 km
# Iteración 80: Mejor costo hasta ahora = 288.25 km
# Iteración 90: Mejor costo hasta ahora = 288.25 km
# Iteración 100: Mejor costo hasta ahora = 288.25 km
# Resultados guardados en: resultados/28_150
#
#
# Procesando archivo: redes/29_150.xlsx
# Generación 50: Mejor distancia = 1207.98 km
# Generación 100: Mejor distancia = 1188.30 km
# Generación 150: Mejor distancia = 1181.60 km
# Generación 200: Mejor distancia = 1130.78 km
# Generación 250: Mejor distancia = 1130.78 km
# Generación 300: Mejor distancia = 1130.78 km
# Generación 350: Mejor distancia = 1130.78 km
# Generación 400: Mejor distancia = 1130.78 km
# Generación 450: Mejor distancia = 1130.78 km
# Generación 500: Mejor distancia = 1130.78 km
# Iteración 10: Mejor costo hasta ahora = 232.28 km
# Iteración 20: Mejor costo hasta ahora = 225.55 km
# Iteración 30: Mejor costo hasta ahora = 224.23 km
# Iteración 40: Mejor costo hasta ahora = 224.23 km
# Iteración 50: Mejor costo hasta ahora = 218.60 km
# Iteración 60: Mejor costo hasta ahora = 218.60 km
# Iteración 70: Mejor costo hasta ahora = 218.60 km
# Iteración 80: Mejor costo hasta ahora = 218.60 km
# Iteración 90: Mejor costo hasta ahora = 218.60 km
# Iteración 100: Mejor costo hasta ahora = 218.60 km
# Resultados guardados en: resultados/29_150
#
#
# Procesando archivo: redes/30_150.xlsx
# Generación 50: Mejor distancia = 1217.14 km
# Generación 100: Mejor distancia = 1217.14 km
# Generación 150: Mejor distancia = 1217.14 km
# Generación 200: Mejor distancia = 1200.13 km
# Generación 250: Mejor distancia = 1137.89 km
# Generación 300: Mejor distancia = 1137.89 km
# Generación 350: Mejor distancia = 1137.89 km
# Generación 400: Mejor distancia = 1137.89 km
# Generación 450: Mejor distancia = 1137.89 km
# Generación 500: Mejor distancia = 1137.89 km
# Iteración 10: Mejor costo hasta ahora = 253.31 km
# Iteración 20: Mejor costo hasta ahora = 253.31 km
# Iteración 30: Mejor costo hasta ahora = 253.31 km
# Iteración 40: Mejor costo hasta ahora = 253.31 km
# Iteración 50: Mejor costo hasta ahora = 253.31 km
# Iteración 60: Mejor costo hasta ahora = 253.31 km
# Iteración 70: Mejor costo hasta ahora = 251.31 km
# Iteración 80: Mejor costo hasta ahora = 251.31 km
# Iteración 90: Mejor costo hasta ahora = 251.31 km
# Iteración 100: Mejor costo hasta ahora = 251.31 km
# Resultados guardados en: resultados/30_150
#
#
# Procesando archivo: redes/31_200.xlsx
# Generación 50: Mejor distancia = 1770.62 km
# Generación 100: Mejor distancia = 1752.40 km
# Generación 150: Mejor distancia = 1752.40 km
# Generación 200: Mejor distancia = 1726.54 km
# Generación 250: Mejor distancia = 1726.54 km
# Generación 300: Mejor distancia = 1726.54 km
# Generación 350: Mejor distancia = 1722.90 km
# Generación 400: Mejor distancia = 1722.90 km
# Generación 450: Mejor distancia = 1722.90 km
# Generación 500: Mejor distancia = 1722.90 km
# Iteración 10: Mejor costo hasta ahora = 334.22 km
# Iteración 20: Mejor costo hasta ahora = 333.42 km
# Iteración 30: Mejor costo hasta ahora = 326.64 km
# Iteración 40: Mejor costo hasta ahora = 326.64 km
# Iteración 50: Mejor costo hasta ahora = 326.64 km
# Iteración 60: Mejor costo hasta ahora = 326.64 km
# Iteración 70: Mejor costo hasta ahora = 325.72 km
# Iteración 80: Mejor costo hasta ahora = 325.72 km
# Iteración 90: Mejor costo hasta ahora = 325.72 km
# Iteración 100: Mejor costo hasta ahora = 325.72 km
# Resultados guardados en: resultados/31_200
#
#
# Procesando archivo: redes/32_200.xlsx
# Generación 50: Mejor distancia = 1681.70 km
# Generación 100: Mejor distancia = 1681.70 km
# Generación 150: Mejor distancia = 1681.70 km
# Generación 200: Mejor distancia = 1680.30 km
# Generación 250: Mejor distancia = 1680.30 km
# Generación 300: Mejor distancia = 1680.30 km
# Generación 350: Mejor distancia = 1680.30 km
# Generación 400: Mejor distancia = 1674.93 km
# Generación 450: Mejor distancia = 1674.93 km
# Generación 500: Mejor distancia = 1674.93 km
# Iteración 10: Mejor costo hasta ahora = 354.02 km
# Iteración 20: Mejor costo hasta ahora = 328.86 km
# Iteración 30: Mejor costo hasta ahora = 328.86 km
# Iteración 40: Mejor costo hasta ahora = 328.86 km
# Iteración 50: Mejor costo hasta ahora = 328.86 km
# Iteración 60: Mejor costo hasta ahora = 328.86 km
# Iteración 70: Mejor costo hasta ahora = 328.86 km
# Iteración 80: Mejor costo hasta ahora = 328.86 km
# Iteración 90: Mejor costo hasta ahora = 328.86 km
# Iteración 100: Mejor costo hasta ahora = 328.86 km
# Resultados guardados en: resultados/32_200
#
#
# Procesando archivo: redes/33_200.xlsx
# Generación 50: Mejor distancia = 1763.84 km
# Generación 100: Mejor distancia = 1759.30 km
# Generación 150: Mejor distancia = 1748.77 km
# Generación 200: Mejor distancia = 1748.77 km
# Generación 250: Mejor distancia = 1728.73 km
# Generación 300: Mejor distancia = 1728.73 km
# Generación 350: Mejor distancia = 1700.45 km
# Generación 400: Mejor distancia = 1700.45 km
# Generación 450: Mejor distancia = 1700.45 km
# Generación 500: Mejor distancia = 1700.45 km
# Iteración 10: Mejor costo hasta ahora = 347.63 km
# Iteración 20: Mejor costo hasta ahora = 332.55 km
# Iteración 30: Mejor costo hasta ahora = 332.55 km
# Iteración 40: Mejor costo hasta ahora = 332.55 km
# Iteración 50: Mejor costo hasta ahora = 332.55 km
# Iteración 60: Mejor costo hasta ahora = 332.20 km
# Iteración 70: Mejor costo hasta ahora = 332.20 km
# Iteración 80: Mejor costo hasta ahora = 332.20 km
# Iteración 90: Mejor costo hasta ahora = 332.20 km
# Iteración 100: Mejor costo hasta ahora = 332.20 km
# Resultados guardados en: resultados/33_200
#
#
# Procesando archivo: redes/34_200.xlsx
# Generación 50: Mejor distancia = 1751.77 km
# Generación 100: Mejor distancia = 1675.00 km
# Generación 150: Mejor distancia = 1675.00 km
# Generación 200: Mejor distancia = 1675.00 km
# Generación 250: Mejor distancia = 1675.00 km
# Generación 300: Mejor distancia = 1675.00 km
# Generación 350: Mejor distancia = 1675.00 km
# Generación 400: Mejor distancia = 1675.00 km
# Generación 450: Mejor distancia = 1675.00 km
# Generación 500: Mejor distancia = 1675.00 km
# Iteración 10: Mejor costo hasta ahora = 340.07 km
# Iteración 20: Mejor costo hasta ahora = 325.17 km
# Iteración 30: Mejor costo hasta ahora = 323.62 km
# Iteración 40: Mejor costo hasta ahora = 318.46 km
# Iteración 50: Mejor costo hasta ahora = 318.46 km
# Iteración 60: Mejor costo hasta ahora = 309.39 km
# Iteración 70: Mejor costo hasta ahora = 309.39 km
# Iteración 80: Mejor costo hasta ahora = 309.39 km
# Iteración 90: Mejor costo hasta ahora = 309.39 km
# Iteración 100: Mejor costo hasta ahora = 309.39 km
# Resultados guardados en: resultados/34_200
#
#
# Procesando archivo: redes/35_200.xlsx
# Generación 50: Mejor distancia = 1719.47 km
# Generación 100: Mejor distancia = 1719.47 km
# Generación 150: Mejor distancia = 1719.47 km
# Generación 200: Mejor distancia = 1719.47 km
# Generación 250: Mejor distancia = 1714.53 km
# Generación 300: Mejor distancia = 1714.53 km
# Generación 350: Mejor distancia = 1714.53 km
# Generación 400: Mejor distancia = 1714.53 km
# Generación 450: Mejor distancia = 1714.53 km
# Generación 500: Mejor distancia = 1714.53 km
# Iteración 10: Mejor costo hasta ahora = 348.82 km
# Iteración 20: Mejor costo hasta ahora = 331.43 km
# Iteración 30: Mejor costo hasta ahora = 331.43 km
# Iteración 40: Mejor costo hasta ahora = 331.43 km
# Iteración 50: Mejor costo hasta ahora = 331.43 km
# Iteración 60: Mejor costo hasta ahora = 331.43 km
# Iteración 70: Mejor costo hasta ahora = 331.43 km
# Iteración 80: Mejor costo hasta ahora = 327.52 km
# Iteración 90: Mejor costo hasta ahora = 327.52 km
# Iteración 100: Mejor costo hasta ahora = 327.52 km
# Resultados guardados en: resultados/35_200
#
#
# Procesando archivo: redes/36_200.xlsx
# Generación 50: Mejor distancia = 1811.42 km
# Generación 100: Mejor distancia = 1753.26 km
# Generación 150: Mejor distancia = 1725.80 km
# Generación 200: Mejor distancia = 1725.80 km
# Generación 250: Mejor distancia = 1718.24 km
# Generación 300: Mejor distancia = 1676.05 km
# Generación 350: Mejor distancia = 1659.07 km
# Generación 400: Mejor distancia = 1659.07 km
# Generación 450: Mejor distancia = 1659.07 km
# Generación 500: Mejor distancia = 1659.07 km
# Iteración 10: Mejor costo hasta ahora = 349.45 km
# Iteración 20: Mejor costo hasta ahora = 341.96 km
# Iteración 30: Mejor costo hasta ahora = 341.36 km
# Iteración 40: Mejor costo hasta ahora = 328.30 km
# Iteración 50: Mejor costo hasta ahora = 328.30 km
# Iteración 60: Mejor costo hasta ahora = 328.30 km
# Iteración 70: Mejor costo hasta ahora = 328.30 km
# Iteración 80: Mejor costo hasta ahora = 328.30 km
# Iteración 90: Mejor costo hasta ahora = 328.30 km
# Iteración 100: Mejor costo hasta ahora = 328.30 km
# Resultados guardados en: resultados/36_200
#
#
# Procesando archivo: redes/37_200.xlsx
# Generación 50: Mejor distancia = 1742.24 km
# Generación 100: Mejor distancia = 1742.24 km
# Generación 150: Mejor distancia = 1741.42 km
# Generación 200: Mejor distancia = 1718.54 km
# Generación 250: Mejor distancia = 1691.73 km
# Generación 300: Mejor distancia = 1679.00 km
# Generación 350: Mejor distancia = 1679.00 km
# Generación 400: Mejor distancia = 1679.00 km
# Generación 450: Mejor distancia = 1679.00 km
# Generación 500: Mejor distancia = 1656.03 km
# Iteración 10: Mejor costo hasta ahora = 319.63 km
# Iteración 20: Mejor costo hasta ahora = 300.79 km
# Iteración 30: Mejor costo hasta ahora = 293.41 km
# Iteración 40: Mejor costo hasta ahora = 293.41 km
# Iteración 50: Mejor costo hasta ahora = 293.41 km
# Iteración 60: Mejor costo hasta ahora = 293.41 km
# Iteración 70: Mejor costo hasta ahora = 293.41 km
# Iteración 80: Mejor costo hasta ahora = 293.41 km
# Iteración 90: Mejor costo hasta ahora = 293.41 km
# Iteración 100: Mejor costo hasta ahora = 293.41 km
# Resultados guardados en: resultados/37_200
#
#
# Procesando archivo: redes/38_200.xlsx
# Generación 50: Mejor distancia = 1764.10 km
# Generación 100: Mejor distancia = 1738.76 km
# Generación 150: Mejor distancia = 1738.76 km
# Generación 200: Mejor distancia = 1676.35 km
# Generación 250: Mejor distancia = 1676.35 km
# Generación 300: Mejor distancia = 1676.35 km
# Generación 350: Mejor distancia = 1676.35 km
# Generación 400: Mejor distancia = 1676.35 km
# Generación 450: Mejor distancia = 1676.35 km
# Generación 500: Mejor distancia = 1676.35 km
# Iteración 10: Mejor costo hasta ahora = 360.12 km
# Iteración 20: Mejor costo hasta ahora = 333.43 km
# Iteración 30: Mejor costo hasta ahora = 328.12 km
# Iteración 40: Mejor costo hasta ahora = 328.12 km
# Iteración 50: Mejor costo hasta ahora = 328.12 km
# Iteración 60: Mejor costo hasta ahora = 328.12 km
# Iteración 70: Mejor costo hasta ahora = 328.12 km
# Iteración 80: Mejor costo hasta ahora = 328.12 km
# Iteración 90: Mejor costo hasta ahora = 328.12 km
# Iteración 100: Mejor costo hasta ahora = 328.12 km
# Resultados guardados en: resultados/38_200
#
#
# Procesando archivo: redes/39_200.xlsx
# Generación 50: Mejor distancia = 1719.11 km
# Generación 100: Mejor distancia = 1661.04 km
# Generación 150: Mejor distancia = 1649.87 km
# Generación 200: Mejor distancia = 1635.32 km
# Generación 250: Mejor distancia = 1635.32 km
# Generación 300: Mejor distancia = 1635.32 km
# Generación 350: Mejor distancia = 1635.32 km
# Generación 400: Mejor distancia = 1613.57 km
# Generación 450: Mejor distancia = 1613.57 km
# Generación 500: Mejor distancia = 1613.57 km
# Iteración 10: Mejor costo hasta ahora = 321.80 km
# Iteración 20: Mejor costo hasta ahora = 302.19 km
# Iteración 30: Mejor costo hasta ahora = 301.93 km
# Iteración 40: Mejor costo hasta ahora = 301.93 km
# Iteración 50: Mejor costo hasta ahora = 296.10 km
# Iteración 60: Mejor costo hasta ahora = 296.10 km
# Iteración 70: Mejor costo hasta ahora = 293.18 km
# Iteración 80: Mejor costo hasta ahora = 293.18 km
# Iteración 90: Mejor costo hasta ahora = 293.18 km
# Iteración 100: Mejor costo hasta ahora = 293.18 km
# Resultados guardados en: resultados/39_200
#
#
# Procesando archivo: redes/40_200.xlsx
# Generación 50: Mejor distancia = 1832.94 km
# Generación 100: Mejor distancia = 1799.09 km
# Generación 150: Mejor distancia = 1799.09 km
# Generación 200: Mejor distancia = 1787.39 km
# Generación 250: Mejor distancia = 1787.39 km
# Generación 300: Mejor distancia = 1787.39 km
# Generación 350: Mejor distancia = 1787.39 km
# Generación 400: Mejor distancia = 1780.22 km
# Generación 450: Mejor distancia = 1780.22 km
# Generación 500: Mejor distancia = 1734.22 km
# Iteración 10: Mejor costo hasta ahora = 344.35 km
# Iteración 20: Mejor costo hasta ahora = 332.83 km
# Iteración 30: Mejor costo hasta ahora = 332.83 km
# Iteración 40: Mejor costo hasta ahora = 324.67 km
# Iteración 50: Mejor costo hasta ahora = 324.67 km
# Iteración 60: Mejor costo hasta ahora = 324.67 km
# Iteración 70: Mejor costo hasta ahora = 324.67 km
# Iteración 80: Mejor costo hasta ahora = 320.52 km
# Iteración 90: Mejor costo hasta ahora = 320.52 km
# Iteración 100: Mejor costo hasta ahora = 320.52 km
# Resultados guardados en: resultados/40_200
