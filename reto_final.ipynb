# %% [markdown]
# ## Librerias y parametros iniciales

# %%
import pandas as pd
import numpy as np
from math import radians, sin, cos, sqrt, atan2
import folium
import random
import os
import json
import warnings
import time

warnings.filterwarnings("ignore")

archivo_entrada = 'tsp_con_coordenadas.xlsx'
path_de_redes = 'redes'
path_de_resultados = 'resultados'

os.makedirs(path_de_redes, exist_ok=True)
os.makedirs(path_de_resultados, exist_ok=True)

df_tsp = pd.read_excel(archivo_entrada)

# %% [markdown]
# ## Generar redes
#
# Se generan las siguientes redes:
#
# - 10 redes con 40 nodos
# - 10 redes con 100 nodos
# - 10 redes con 150 nodos
# - 10 redes con 200 nodos

# %%
generar = False  # Cambiar a True para generar las redes si es necesario

configuraciones = {
    40: 10,
    100: 10,
    150: 10,
    200: 10
}

def generar_redes():
    numero_red = 1

    for nodos, cantidad in configuraciones.items():
        for _ in range(cantidad):
            # Crear un dataframe vacío con la misma estructura que el original
            columnas = df_tsp.columns
            red_df = pd.DataFrame(columns=columnas)

            # Lista de índices seleccionados para evitar duplicados
            nodos_seleccionados = set()

            # Seleccionar nodos aleatorios
            while len(red_df) < nodos:
                nodo = df_tsp.sample(n=1, random_state=random.randint(1, 10000))
                if nodo.index[0] not in nodos_seleccionados:
                    nodos_seleccionados.add(nodo.index[0])
                    red_df = pd.concat([red_df, nodo], ignore_index=True)

            # Guardar el DataFrame en un archivo Excel
            nombre_archivo = f"redes/{numero_red}_{nodos}.xlsx"
            red_df.to_excel(nombre_archivo, index=False)

            # Incrementar el número de red
            numero_red += 1

if generar == True:
    generar_redes()

# %% [markdown]
# ## Funciones auxiliares

# %%
def haversine_distance(coord1, coord2):
    R = 6371
    lat1, lon1 = coord1
    lat2, lon2 = coord2

    lat1_rad, lon1_rad = radians(lat1), radians(lon1)
    lat2_rad, lon2_rad = radians(lat2), radians(lon2)

    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad

    a = sin(dlat/2)**2 + cos(lat1_rad)*cos(lat2_rad)*sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

def crear_matriz_distancias(df_red):
    coordenadas = df_red[['latitud', 'longitud']].values
    n = len(coordenadas)
    matriz_distancias = np.zeros((n, n))

    for i in range(n):
        for j in range(i, n):
            distancia = haversine_distance(coordenadas[i], coordenadas[j])
            matriz_distancias[i, j] = distancia
            matriz_distancias[j, i] = distancia

    return matriz_distancias

# %% [markdown]
# ## Algoritmo genético

# %%
def inicializar_poblacion(tamano_poblacion, indices_ciudades):
    poblacion = []
    for _ in range(tamano_poblacion):
        individuo = indices_ciudades.copy()
        random.shuffle(individuo)
        poblacion.append(individuo)
    return poblacion

def calcular_aptitud(individuo, matriz_distancias):
    distancia_total = 0
    for i in range(len(individuo)):
        ciudad_origen = individuo[i]
        ciudad_destino = individuo[(i + 1) % len(individuo)]
        distancia_total += matriz_distancias[ciudad_origen][ciudad_destino]
    return distancia_total

def seleccionar_padres(poblacion, aptitudes, num_padres):
    padres_indices = np.argsort(aptitudes)[:num_padres]
    padres = [poblacion[i] for i in padres_indices]
    return padres

def cruzar_padres(padre1, padre2):
    tamano = len(padre1)
    inicio, fin = sorted(random.sample(range(tamano), 2))
    hijo = [None]*tamano
    hijo[inicio:fin+1] = padre1[inicio:fin+1]

    pointer = 0
    for i in range(tamano):
        if hijo[i] is None:
            while padre2[pointer] in hijo:
                pointer += 1
            hijo[i] = padre2[pointer]
            pointer += 1
    return hijo

def mutar_individuo(individuo, tasa_mutacion):
    for i in range(len(individuo)):
        if random.random() < tasa_mutacion:
            j = random.randint(0, len(individuo)-1)
            individuo[i], individuo[j] = individuo[j], individuo[i]
    return individuo

def algoritmo_genetico_tsp(matriz_distancias, tamano_poblacion=100, num_generaciones=100, tasa_mutacion=0.01):
    indices_ciudades = list(range(len(matriz_distancias)))
    poblacion = inicializar_poblacion(tamano_poblacion, indices_ciudades)
    mejor_distancia = float('inf')
    mejor_ruta = None

    for generacion in range(num_generaciones):
        aptitudes = [calcular_aptitud(individuo, matriz_distancias) for individuo in poblacion]
        distancia_actual = min(aptitudes)
        if distancia_actual < mejor_distancia:
            mejor_distancia = distancia_actual
            mejor_ruta = poblacion[np.argmin(aptitudes)]

        num_padres = tamano_poblacion // 2
        padres = seleccionar_padres(poblacion, aptitudes, num_padres)

        siguiente_generacion = []
        while len(siguiente_generacion) < tamano_poblacion:
            padre1, padre2 = random.sample(padres, 2)
            hijo = cruzar_padres(padre1, padre2)
            hijo = mutar_individuo(hijo, tasa_mutacion)
            siguiente_generacion.append(hijo)

        poblacion = siguiente_generacion

        if (generacion + 1) % 50 == 0:
            print(f"Generación {generacion + 1}: Mejor distancia = {mejor_distancia:.2f} km")

    return mejor_ruta, mejor_distancia

# %% [markdown]
# ## Algoritmo colonia de hormigas (ACO)

# %%
def calcular_heuristica(costos):
    num_nodos = costos.shape[0]
    heuristica = np.zeros_like(costos)
    for i in range(num_nodos):
        for j in range(num_nodos):
            if costos[i, j] > 0 and not np.isinf(costos[i, j]):
                heuristica[i, j] = 1 / costos[i, j]
            else:
                heuristica[i, j] = 0
    return heuristica

def calcular_probabilidades(feromonas, heuristica, nodo_actual, visitados, alpha, beta):
    num_nodos = len(feromonas)
    probabilidades = np.zeros(num_nodos)
    for j in range(num_nodos):
        if j not in visitados:
            probabilidades[j] = (feromonas[nodo_actual, j] ** alpha) * (heuristica[nodo_actual, j] ** beta)
    suma_probabilidades = np.sum(probabilidades)
    if suma_probabilidades == 0:
        return probabilidades
    return probabilidades / suma_probabilidades

def construir_camino(feromonas, heuristica, costos, alpha, beta):
    num_nodos = costos.shape[0]
    nodo_actual = random.randint(0, num_nodos - 1)
    camino = [nodo_actual]
    costo_total = 0
    visitados = set(camino)

    while len(camino) < num_nodos:
        probabilidades = calcular_probabilidades(feromonas, heuristica, nodo_actual, visitados, alpha, beta)
        if np.sum(probabilidades) == 0:
            nodos_no_visitados = list(set(range(num_nodos)) - visitados)
            siguiente_nodo = random.choice(nodos_no_visitados)
        else:
            siguiente_nodo = random.choices(range(num_nodos), weights=probabilidades, k=1)[0]
        costo_total += costos[nodo_actual, siguiente_nodo]
        camino.append(siguiente_nodo)
        visitados.add(siguiente_nodo)
        nodo_actual = siguiente_nodo

    costo_total += costos[camino[-1], camino[0]]
    camino.append(camino[0])

    return camino, costo_total

def actualizar_feromonas(feromonas, soluciones, rho):
    feromonas *= (1 - rho)
    for camino, costo in soluciones:
        for i in range(len(camino) - 1):
            feromonas[camino[i], camino[i + 1]] += 1 / costo

def ACO(costos, num_hormigas=500, num_iteraciones=100, alpha=1.0, beta=2.0, rho=0.5):
    num_nodos = costos.shape[0]
    mejor_camino = None
    mejor_costo = float('inf')

    feromonas = np.ones((num_nodos, num_nodos)) * 0.1
    heuristica = calcular_heuristica(costos)

    for iteracion in range(num_iteraciones):
        soluciones = []
        for _ in range(num_hormigas):
            camino, costo = construir_camino(feromonas, heuristica, costos, alpha, beta)
            soluciones.append((camino, costo))
            if costo < mejor_costo:
                mejor_camino = camino
                mejor_costo = costo

        actualizar_feromonas(feromonas, soluciones, rho)

        if (iteracion + 1) % 10 == 0:
            print(f"Iteración {iteracion+1}: Mejor costo hasta ahora = {mejor_costo:.2f} km")

    return mejor_camino, mejor_costo

# %% [markdown]
# ## Procesar las redes

# %%
def procesar_redes(archivo):
    df_red = pd.read_excel(archivo)

    matriz_distancias = crear_matriz_distancias(df_red)

    start_genetico = time.time()
    mejor_ruta_genetico, mejor_distancia_genetico = algoritmo_genetico_tsp(matriz_distancias, tamano_poblacion=100, num_generaciones=500, tasa_mutacion=0.01)
    end_genetico = time.time()

    start_aco = time.time()
    mejor_ruta_aco, mejor_distancia_aco = ACO(matriz_distancias, num_hormigas=500, num_iteraciones=100, alpha=1.0, beta=2.0, rho=0.5)
    end_aco = time.time()

    tiempo_genetico = end_genetico - start_genetico
    tiempo_aco = end_aco - start_aco

    return mejor_ruta_genetico, mejor_distancia_genetico, tiempo_genetico, mejor_ruta_aco, mejor_distancia_aco, tiempo_aco

def crear_visualizacion(df_red, mejor_ruta, nombre_archivo):
    coordenadas = df_red[['latitud', 'longitud']].values
    ruta_coordenadas = coordenadas[mejor_ruta]
    ruta_coordenadas = np.vstack([ruta_coordenadas, ruta_coordenadas[0]])

    centro_lat = np.mean(coordenadas[:, 0])
    centro_lon = np.mean(coordenadas[:, 1])
    mapa = folium.Map(location=[centro_lat, centro_lon], zoom_start=12)

    for idx, coord in enumerate(ruta_coordenadas[:-1]):
        folium.Marker(location=coord, popup=f"Parada {idx + 1}").add_to(mapa)

    folium.PolyLine(ruta_coordenadas, color="blue", weight=2.5, opacity=1).add_to(mapa)

    return mapa.save(nombre_archivo)

def generar_archivos_inclusion(archivo):
        df_red = pd.read_excel(archivo)
        matriz_distancias = crear_matriz_distancias(df_red)
        n = len(df_red)

        # Crear el archivo de inclusión
        nombre_archivo_inc = f"{path_de_resultados}/{archivo.split('/')[-1].split('.')[0]}/gams_{archivo.split('/')[-1].split('.')[0]}.inc"
        with open(nombre_archivo_inc, 'w') as f:
            # Escribir encabezado (índices de columnas)
            f.write("    ")  # Espacio para el índice de filas
            for j in range(n):
                f.write(f"{j:<8}")  # Alinear columnas con espacio fijo
            f.write("\n")

            # Escribir filas de la matriz
            for i in range(n):
                f.write(f"{i:<4}")  # Índice de la fila
                for j in range(n):
                    f.write(f"{matriz_distancias[i][j]:<8.1f}")  # Valor de la matriz con 1 decimal
                f.write("\n")

        print(f"Archivo de inclusión generado: {nombre_archivo_inc}")

def procesar_archivo(archivo):
    print(f"Procesando archivo: {archivo}")
    df_red = pd.read_excel(archivo)

    path_de_resultado_base = f"{path_de_resultados}/{archivo.split('/')[-1].split('.')[0]}"
    os.makedirs(path_de_resultado_base, exist_ok=True)

    path_de_resultado_json = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}.json"
    path_de_visualizacion_genetico = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}_genetico.html"
    path_de_visualizacion_aco = f"{path_de_resultado_base}/{archivo.split('/')[-1].split('.')[0]}_aco.html"

    mejor_ruta_genetico, mejor_distancia_genetico, tiempo_genetico, mejor_ruta_aco, mejor_distancia_aco, tiempo_aco = procesar_redes(archivo)

    # Generar resultados en un archivo json
    with open(path_de_resultado_json, "w") as f:
        json.dump({
            "genetico": {
                "ruta": mejor_ruta_genetico,
                "distancia": mejor_distancia_genetico,
                "tiempo": tiempo_genetico
            },
            "aco": {
                "ruta": mejor_ruta_aco,
                "distancia": mejor_distancia_aco,
                "tiempo": tiempo_aco
            }
        }, f)

    # Crear visualización de la mejor ruta encontrada por el algoritmo genético
    crear_visualizacion(df_red, mejor_ruta_genetico, path_de_visualizacion_genetico)
    crear_visualizacion(df_red, mejor_ruta_aco, path_de_visualizacion_aco)
    print(f"Resultados guardados en: {path_de_resultado_base}\n\n")

# Procesar cada archivo de red
paths = [f"{path_de_redes}/{archivo}" for archivo in os.listdir(path_de_redes)]
paths_sorted = sorted(paths, key=lambda x: int(x.split('/')[1].split('_')[0]))

for archivo in paths_sorted:
    procesar_archivo(archivo)
    generar_archivos_inclusion(archivo)
# Out:
# Procesando archivo: redes/1_40.xlsx
# Generación 50: Mejor distancia = 317.71 km
# Generación 100: Mejor distancia = 258.13 km
# Generación 150: Mejor distancia = 182.38 km
# Generación 200: Mejor distancia = 173.75 km
# Generación 250: Mejor distancia = 171.45 km
# Generación 300: Mejor distancia = 171.45 km
# Generación 350: Mejor distancia = 171.27 km
# Generación 400: Mejor distancia = 171.27 km
# Generación 450: Mejor distancia = 171.27 km
# Generación 500: Mejor distancia = 171.27 km
# Iteración 10: Mejor costo hasta ahora = 161.04 km
# Iteración 20: Mejor costo hasta ahora = 156.09 km
# Iteración 30: Mejor costo hasta ahora = 156.09 km
# Iteración 40: Mejor costo hasta ahora = 156.09 km
# Iteración 50: Mejor costo hasta ahora = 156.09 km
# Iteración 60: Mejor costo hasta ahora = 156.09 km
# Iteración 70: Mejor costo hasta ahora = 156.09 km
# Iteración 80: Mejor costo hasta ahora = 156.09 km
# Iteración 90: Mejor costo hasta ahora = 156.09 km
# Iteración 100: Mejor costo hasta ahora = 156.09 km
# Resultados guardados en: resultados/1_40
#
#
# Archivo de inclusión generado: resultados/1_40/gams_1_40.inc
# Procesando archivo: redes/2_40.xlsx
# Generación 50: Mejor distancia = 267.59 km
# Generación 100: Mejor distancia = 251.72 km
# Generación 150: Mejor distancia = 251.72 km
# Generación 200: Mejor distancia = 243.00 km
# Generación 250: Mejor distancia = 196.75 km
# Generación 300: Mejor distancia = 172.58 km
# Generación 350: Mejor distancia = 171.19 km
# Generación 400: Mejor distancia = 169.55 km
# Generación 450: Mejor distancia = 169.00 km
# Generación 500: Mejor distancia = 169.00 km
# Iteración 10: Mejor costo hasta ahora = 156.64 km
# Iteración 20: Mejor costo hasta ahora = 151.57 km
# Iteración 30: Mejor costo hasta ahora = 151.57 km
# Iteración 40: Mejor costo hasta ahora = 151.57 km
# Iteración 50: Mejor costo hasta ahora = 151.08 km
# Iteración 60: Mejor costo hasta ahora = 151.08 km
# Iteración 70: Mejor costo hasta ahora = 151.08 km
# Iteración 80: Mejor costo hasta ahora = 151.08 km
# Iteración 90: Mejor costo hasta ahora = 151.08 km
# Iteración 100: Mejor costo hasta ahora = 151.08 km
# Resultados guardados en: resultados/2_40
#
#
# Archivo de inclusión generado: resultados/2_40/gams_2_40.inc
# Procesando archivo: redes/3_40.xlsx
# Generación 50: Mejor distancia = 227.13 km
# Generación 100: Mejor distancia = 214.12 km
# Generación 150: Mejor distancia = 174.75 km
# Generación 200: Mejor distancia = 139.14 km
# Generación 250: Mejor distancia = 127.29 km
# Generación 300: Mejor distancia = 122.28 km
# Generación 350: Mejor distancia = 119.64 km
# Generación 400: Mejor distancia = 119.53 km
# Generación 450: Mejor distancia = 119.38 km
# Generación 500: Mejor distancia = 119.38 km
# Iteración 10: Mejor costo hasta ahora = 104.88 km
# Iteración 20: Mejor costo hasta ahora = 104.87 km
# Iteración 30: Mejor costo hasta ahora = 104.11 km
# Iteración 40: Mejor costo hasta ahora = 104.11 km
# Iteración 50: Mejor costo hasta ahora = 104.11 km
# Iteración 60: Mejor costo hasta ahora = 104.11 km
# Iteración 70: Mejor costo hasta ahora = 104.11 km
# Iteración 80: Mejor costo hasta ahora = 104.11 km
# Iteración 90: Mejor costo hasta ahora = 104.11 km
# Iteración 100: Mejor costo hasta ahora = 104.11 km
# Resultados guardados en: resultados/3_40
#
#
# Archivo de inclusión generado: resultados/3_40/gams_3_40.inc
# Procesando archivo: redes/4_40.xlsx
# Generación 50: Mejor distancia = 212.38 km
# Generación 100: Mejor distancia = 187.81 km
# Generación 150: Mejor distancia = 174.39 km
# Generación 200: Mejor distancia = 126.42 km
# Generación 250: Mejor distancia = 120.13 km
# Generación 300: Mejor distancia = 111.88 km
# Generación 350: Mejor distancia = 110.76 km
# Generación 400: Mejor distancia = 110.76 km
# Generación 450: Mejor distancia = 110.47 km
# Generación 500: Mejor distancia = 109.73 km
# Iteración 10: Mejor costo hasta ahora = 104.02 km
# Iteración 20: Mejor costo hasta ahora = 102.94 km
# Iteración 30: Mejor costo hasta ahora = 101.27 km
# Iteración 40: Mejor costo hasta ahora = 101.27 km
# Iteración 50: Mejor costo hasta ahora = 101.27 km
# Iteración 60: Mejor costo hasta ahora = 101.27 km
# Iteración 70: Mejor costo hasta ahora = 101.27 km
# Iteración 80: Mejor costo hasta ahora = 101.27 km
# Iteración 90: Mejor costo hasta ahora = 101.27 km
# Iteración 100: Mejor costo hasta ahora = 101.27 km
# Resultados guardados en: resultados/4_40
#
#
# Archivo de inclusión generado: resultados/4_40/gams_4_40.inc
# Procesando archivo: redes/5_40.xlsx
# Generación 50: Mejor distancia = 229.59 km
# Generación 100: Mejor distancia = 172.74 km
# Generación 150: Mejor distancia = 148.94 km
# Generación 200: Mejor distancia = 144.79 km
# Generación 250: Mejor distancia = 142.73 km
# Generación 300: Mejor distancia = 142.03 km
# Generación 350: Mejor distancia = 140.54 km
# Generación 400: Mejor distancia = 137.77 km
# Generación 450: Mejor distancia = 136.31 km
# Generación 500: Mejor distancia = 134.56 km
# Iteración 10: Mejor costo hasta ahora = 111.63 km
# Iteración 20: Mejor costo hasta ahora = 111.63 km
# Iteración 30: Mejor costo hasta ahora = 111.63 km
# Iteración 40: Mejor costo hasta ahora = 111.63 km
# Iteración 50: Mejor costo hasta ahora = 111.63 km
# Iteración 60: Mejor costo hasta ahora = 111.63 km
# Iteración 70: Mejor costo hasta ahora = 111.63 km
# Iteración 80: Mejor costo hasta ahora = 111.63 km
# Iteración 90: Mejor costo hasta ahora = 111.63 km
# Iteración 100: Mejor costo hasta ahora = 111.63 km
# Resultados guardados en: resultados/5_40
#
#
# Archivo de inclusión generado: resultados/5_40/gams_5_40.inc
# Procesando archivo: redes/6_40.xlsx
# Generación 50: Mejor distancia = 259.64 km
# Generación 100: Mejor distancia = 193.14 km
# Generación 150: Mejor distancia = 166.10 km
# Generación 200: Mejor distancia = 165.71 km
# Generación 250: Mejor distancia = 163.14 km
# Generación 300: Mejor distancia = 157.19 km
# Generación 350: Mejor distancia = 157.19 km
# Generación 400: Mejor distancia = 150.44 km
# Generación 450: Mejor distancia = 150.44 km
# Generación 500: Mejor distancia = 150.44 km
# Iteración 10: Mejor costo hasta ahora = 118.98 km
# Iteración 20: Mejor costo hasta ahora = 118.68 km
# Iteración 30: Mejor costo hasta ahora = 118.18 km
# Iteración 40: Mejor costo hasta ahora = 118.18 km
# Iteración 50: Mejor costo hasta ahora = 118.18 km
# Iteración 60: Mejor costo hasta ahora = 118.18 km
# Iteración 70: Mejor costo hasta ahora = 118.18 km
# Iteración 80: Mejor costo hasta ahora = 117.94 km
# Iteración 90: Mejor costo hasta ahora = 117.94 km
# Iteración 100: Mejor costo hasta ahora = 117.94 km
# Resultados guardados en: resultados/6_40
#
#
# Archivo de inclusión generado: resultados/6_40/gams_6_40.inc
# Procesando archivo: redes/7_40.xlsx
# Generación 50: Mejor distancia = 238.11 km
# Generación 100: Mejor distancia = 209.77 km
# Generación 150: Mejor distancia = 154.19 km
# Generación 200: Mejor distancia = 149.96 km
# Generación 250: Mejor distancia = 149.44 km
# Generación 300: Mejor distancia = 146.05 km
# Generación 350: Mejor distancia = 146.05 km
# Generación 400: Mejor distancia = 146.05 km
# Generación 450: Mejor distancia = 146.05 km
# Generación 500: Mejor distancia = 146.05 km
# Iteración 10: Mejor costo hasta ahora = 114.69 km
# Iteración 20: Mejor costo hasta ahora = 110.86 km
# Iteración 30: Mejor costo hasta ahora = 110.86 km
# Iteración 40: Mejor costo hasta ahora = 110.86 km
# Iteración 50: Mejor costo hasta ahora = 110.86 km
# Iteración 60: Mejor costo hasta ahora = 110.86 km
# Iteración 70: Mejor costo hasta ahora = 110.86 km
# Iteración 80: Mejor costo hasta ahora = 110.86 km
# Iteración 90: Mejor costo hasta ahora = 110.86 km
# Iteración 100: Mejor costo hasta ahora = 110.86 km
# Resultados guardados en: resultados/7_40
#
#
# Archivo de inclusión generado: resultados/7_40/gams_7_40.inc
# Procesando archivo: redes/8_40.xlsx
# Generación 50: Mejor distancia = 274.92 km
# Generación 100: Mejor distancia = 246.82 km
# Generación 150: Mejor distancia = 153.83 km
# Generación 200: Mejor distancia = 145.49 km
# Generación 250: Mejor distancia = 138.56 km
# Generación 300: Mejor distancia = 138.56 km
# Generación 350: Mejor distancia = 137.34 km
# Generación 400: Mejor distancia = 137.34 km
# Generación 450: Mejor distancia = 137.34 km
# Generación 500: Mejor distancia = 137.34 km
# Iteración 10: Mejor costo hasta ahora = 133.85 km
# Iteración 20: Mejor costo hasta ahora = 131.98 km
# Iteración 30: Mejor costo hasta ahora = 131.93 km
# Iteración 40: Mejor costo hasta ahora = 131.31 km
# Iteración 50: Mejor costo hasta ahora = 131.17 km
# Iteración 60: Mejor costo hasta ahora = 130.70 km
# Iteración 70: Mejor costo hasta ahora = 130.70 km
# Iteración 80: Mejor costo hasta ahora = 130.70 km
# Iteración 90: Mejor costo hasta ahora = 130.70 km
# Iteración 100: Mejor costo hasta ahora = 130.70 km
# Resultados guardados en: resultados/8_40
#
#
# Archivo de inclusión generado: resultados/8_40/gams_8_40.inc
# Procesando archivo: redes/9_40.xlsx
# Generación 50: Mejor distancia = 271.98 km
# Generación 100: Mejor distancia = 231.41 km
# Generación 150: Mejor distancia = 198.80 km
# Generación 200: Mejor distancia = 185.14 km
# Generación 250: Mejor distancia = 183.86 km
# Generación 300: Mejor distancia = 179.98 km
# Generación 350: Mejor distancia = 179.97 km
# Generación 400: Mejor distancia = 179.90 km
# Generación 450: Mejor distancia = 179.90 km
# Generación 500: Mejor distancia = 179.90 km
# Iteración 10: Mejor costo hasta ahora = 152.50 km
# Iteración 20: Mejor costo hasta ahora = 147.39 km
# Iteración 30: Mejor costo hasta ahora = 147.39 km
# Iteración 40: Mejor costo hasta ahora = 147.39 km
# Iteración 50: Mejor costo hasta ahora = 147.39 km
# Iteración 60: Mejor costo hasta ahora = 147.36 km
# Iteración 70: Mejor costo hasta ahora = 147.36 km
# Iteración 80: Mejor costo hasta ahora = 147.36 km
# Iteración 90: Mejor costo hasta ahora = 147.36 km
# Iteración 100: Mejor costo hasta ahora = 147.36 km
# Resultados guardados en: resultados/9_40
#
#
# Archivo de inclusión generado: resultados/9_40/gams_9_40.inc
# Procesando archivo: redes/10_40.xlsx
# Generación 50: Mejor distancia = 242.47 km
# Generación 100: Mejor distancia = 191.10 km
# Generación 150: Mejor distancia = 173.92 km
# Generación 200: Mejor distancia = 169.48 km
# Generación 250: Mejor distancia = 166.81 km
# Generación 300: Mejor distancia = 166.81 km
# Generación 350: Mejor distancia = 165.96 km
# Generación 400: Mejor distancia = 165.96 km
# Generación 450: Mejor distancia = 165.96 km
# Generación 500: Mejor distancia = 165.96 km
# Iteración 10: Mejor costo hasta ahora = 156.56 km
# Iteración 20: Mejor costo hasta ahora = 154.77 km
# Iteración 30: Mejor costo hasta ahora = 153.51 km
# Iteración 40: Mejor costo hasta ahora = 153.51 km
# Iteración 50: Mejor costo hasta ahora = 153.51 km
# Iteración 60: Mejor costo hasta ahora = 153.51 km
# Iteración 70: Mejor costo hasta ahora = 153.51 km
# Iteración 80: Mejor costo hasta ahora = 153.51 km
# Iteración 90: Mejor costo hasta ahora = 153.51 km
# Iteración 100: Mejor costo hasta ahora = 153.51 km
# Resultados guardados en: resultados/10_40
#
#
# Archivo de inclusión generado: resultados/10_40/gams_10_40.inc
# Procesando archivo: redes/11_100.xlsx
# Generación 50: Mejor distancia = 759.06 km
# Generación 100: Mejor distancia = 759.06 km
# Generación 150: Mejor distancia = 751.82 km
# Generación 200: Mejor distancia = 749.06 km
# Generación 250: Mejor distancia = 749.06 km
# Generación 300: Mejor distancia = 746.14 km
# Generación 350: Mejor distancia = 746.14 km
# Generación 400: Mejor distancia = 736.94 km
# Generación 450: Mejor distancia = 732.52 km
# Generación 500: Mejor distancia = 732.52 km
# Iteración 10: Mejor costo hasta ahora = 232.07 km
# Iteración 20: Mejor costo hasta ahora = 221.58 km
# Iteración 30: Mejor costo hasta ahora = 216.42 km
# Iteración 40: Mejor costo hasta ahora = 216.42 km
# Iteración 50: Mejor costo hasta ahora = 216.42 km
# Iteración 60: Mejor costo hasta ahora = 216.42 km
# Iteración 70: Mejor costo hasta ahora = 216.12 km
# Iteración 80: Mejor costo hasta ahora = 214.53 km
# Iteración 90: Mejor costo hasta ahora = 214.53 km
# Iteración 100: Mejor costo hasta ahora = 214.53 km
# Resultados guardados en: resultados/11_100
#
#
# Archivo de inclusión generado: resultados/11_100/gams_11_100.inc
# Procesando archivo: redes/12_100.xlsx
# Generación 50: Mejor distancia = 782.06 km
# Generación 100: Mejor distancia = 762.39 km
# Generación 150: Mejor distancia = 714.82 km
# Generación 200: Mejor distancia = 714.82 km
# Generación 250: Mejor distancia = 714.82 km
# Generación 300: Mejor distancia = 714.82 km
# Generación 350: Mejor distancia = 714.82 km
# Generación 400: Mejor distancia = 714.82 km
# Generación 450: Mejor distancia = 714.82 km
# Generación 500: Mejor distancia = 714.82 km
# Iteración 10: Mejor costo hasta ahora = 182.86 km
# Iteración 20: Mejor costo hasta ahora = 181.03 km
# Iteración 30: Mejor costo hasta ahora = 174.53 km
# Iteración 40: Mejor costo hasta ahora = 174.53 km
# Iteración 50: Mejor costo hasta ahora = 174.53 km
# Iteración 60: Mejor costo hasta ahora = 174.21 km
# Iteración 70: Mejor costo hasta ahora = 173.61 km
# Iteración 80: Mejor costo hasta ahora = 170.50 km
# Iteración 90: Mejor costo hasta ahora = 170.50 km
# Iteración 100: Mejor costo hasta ahora = 170.50 km
# Resultados guardados en: resultados/12_100
#
#
# Archivo de inclusión generado: resultados/12_100/gams_12_100.inc
# Procesando archivo: redes/13_100.xlsx
# Generación 50: Mejor distancia = 796.00 km
# Generación 100: Mejor distancia = 750.26 km
# Generación 150: Mejor distancia = 713.74 km
# Generación 200: Mejor distancia = 686.05 km
# Generación 250: Mejor distancia = 686.05 km
# Generación 300: Mejor distancia = 686.05 km
# Generación 350: Mejor distancia = 686.05 km
# Generación 400: Mejor distancia = 686.05 km
# Generación 450: Mejor distancia = 686.05 km
# Generación 500: Mejor distancia = 686.05 km
# Iteración 10: Mejor costo hasta ahora = 181.61 km
# Iteración 20: Mejor costo hasta ahora = 175.68 km
# Iteración 30: Mejor costo hasta ahora = 175.68 km
# Iteración 40: Mejor costo hasta ahora = 175.68 km
# Iteración 50: Mejor costo hasta ahora = 174.92 km
# Iteración 60: Mejor costo hasta ahora = 174.92 km
# Iteración 70: Mejor costo hasta ahora = 174.79 km
# Iteración 80: Mejor costo hasta ahora = 172.52 km
# Iteración 90: Mejor costo hasta ahora = 172.35 km
# Iteración 100: Mejor costo hasta ahora = 172.35 km
# Resultados guardados en: resultados/13_100
#
#
# Archivo de inclusión generado: resultados/13_100/gams_13_100.inc
# Procesando archivo: redes/14_100.xlsx
# Generación 50: Mejor distancia = 746.85 km
# Generación 100: Mejor distancia = 724.15 km
# Generación 150: Mejor distancia = 678.19 km
# Generación 200: Mejor distancia = 678.19 km
# Generación 250: Mejor distancia = 664.97 km
# Generación 300: Mejor distancia = 664.97 km
# Generación 350: Mejor distancia = 664.97 km
# Generación 400: Mejor distancia = 664.97 km
# Generación 450: Mejor distancia = 664.97 km
# Generación 500: Mejor distancia = 664.97 km
# Iteración 10: Mejor costo hasta ahora = 175.99 km
# Iteración 20: Mejor costo hasta ahora = 171.70 km
# Iteración 30: Mejor costo hasta ahora = 167.61 km
# Iteración 40: Mejor costo hasta ahora = 167.26 km
# Iteración 50: Mejor costo hasta ahora = 166.39 km
# Iteración 60: Mejor costo hasta ahora = 164.45 km
# Iteración 70: Mejor costo hasta ahora = 164.42 km
# Iteración 80: Mejor costo hasta ahora = 164.05 km
# Iteración 90: Mejor costo hasta ahora = 164.05 km
# Iteración 100: Mejor costo hasta ahora = 164.05 km
# Resultados guardados en: resultados/14_100
#
#
# Archivo de inclusión generado: resultados/14_100/gams_14_100.inc
# Procesando archivo: redes/15_100.xlsx
# Generación 50: Mejor distancia = 848.42 km
# Generación 100: Mejor distancia = 824.40 km
# Generación 150: Mejor distancia = 791.65 km
# Generación 200: Mejor distancia = 761.68 km
# Generación 250: Mejor distancia = 761.68 km
# Generación 300: Mejor distancia = 761.68 km
# Generación 350: Mejor distancia = 761.68 km
# Generación 400: Mejor distancia = 761.68 km
# Generación 450: Mejor distancia = 761.68 km
# Generación 500: Mejor distancia = 761.68 km
# Iteración 10: Mejor costo hasta ahora = 266.96 km
# Iteración 20: Mejor costo hasta ahora = 259.88 km
# Iteración 30: Mejor costo hasta ahora = 259.88 km
# Iteración 40: Mejor costo hasta ahora = 259.88 km
# Iteración 50: Mejor costo hasta ahora = 259.88 km
# Iteración 60: Mejor costo hasta ahora = 259.88 km
# Iteración 70: Mejor costo hasta ahora = 257.59 km
# Iteración 80: Mejor costo hasta ahora = 257.59 km
# Iteración 90: Mejor costo hasta ahora = 257.59 km
# Iteración 100: Mejor costo hasta ahora = 257.59 km
# Resultados guardados en: resultados/15_100
#
#
# Archivo de inclusión generado: resultados/15_100/gams_15_100.inc
# Procesando archivo: redes/16_100.xlsx
# Generación 50: Mejor distancia = 794.91 km
# Generación 100: Mejor distancia = 772.21 km
# Generación 150: Mejor distancia = 754.57 km
# Generación 200: Mejor distancia = 754.57 km
# Generación 250: Mejor distancia = 754.57 km
# Generación 300: Mejor distancia = 754.57 km
# Generación 350: Mejor distancia = 754.57 km
# Generación 400: Mejor distancia = 754.57 km
# Generación 450: Mejor distancia = 744.46 km
# Generación 500: Mejor distancia = 735.07 km
# Iteración 10: Mejor costo hasta ahora = 212.62 km
# Iteración 20: Mejor costo hasta ahora = 205.74 km
# Iteración 30: Mejor costo hasta ahora = 205.74 km
# Iteración 40: Mejor costo hasta ahora = 201.58 km
# Iteración 50: Mejor costo hasta ahora = 201.58 km
# Iteración 60: Mejor costo hasta ahora = 201.58 km
# Iteración 70: Mejor costo hasta ahora = 200.44 km
# Iteración 80: Mejor costo hasta ahora = 200.44 km
# Iteración 90: Mejor costo hasta ahora = 200.44 km
# Iteración 100: Mejor costo hasta ahora = 200.44 km
# Resultados guardados en: resultados/16_100
#
#
# Archivo de inclusión generado: resultados/16_100/gams_16_100.inc
# Procesando archivo: redes/17_100.xlsx
# Generación 50: Mejor distancia = 767.40 km
# Generación 100: Mejor distancia = 726.17 km
# Generación 150: Mejor distancia = 726.17 km
# Generación 200: Mejor distancia = 726.17 km
# Generación 250: Mejor distancia = 726.17 km
# Generación 300: Mejor distancia = 723.06 km
# Generación 350: Mejor distancia = 723.06 km
# Generación 400: Mejor distancia = 723.06 km
# Generación 450: Mejor distancia = 723.06 km
# Generación 500: Mejor distancia = 723.06 km
# Iteración 10: Mejor costo hasta ahora = 211.09 km
# Iteración 20: Mejor costo hasta ahora = 207.37 km
# Iteración 30: Mejor costo hasta ahora = 205.45 km
# Iteración 40: Mejor costo hasta ahora = 197.18 km
# Iteración 50: Mejor costo hasta ahora = 197.18 km
# Iteración 60: Mejor costo hasta ahora = 197.18 km
# Iteración 70: Mejor costo hasta ahora = 197.18 km
# Iteración 80: Mejor costo hasta ahora = 197.18 km
# Iteración 90: Mejor costo hasta ahora = 197.18 km
# Iteración 100: Mejor costo hasta ahora = 197.18 km
# Resultados guardados en: resultados/17_100
#
#
# Archivo de inclusión generado: resultados/17_100/gams_17_100.inc
# Procesando archivo: redes/18_100.xlsx
# Generación 50: Mejor distancia = 821.95 km
# Generación 100: Mejor distancia = 786.38 km
# Generación 150: Mejor distancia = 786.38 km
# Generación 200: Mejor distancia = 783.79 km
# Generación 250: Mejor distancia = 783.79 km
# Generación 300: Mejor distancia = 783.79 km
# Generación 350: Mejor distancia = 766.88 km
# Generación 400: Mejor distancia = 766.88 km
# Generación 450: Mejor distancia = 766.88 km
# Generación 500: Mejor distancia = 766.88 km
# Iteración 10: Mejor costo hasta ahora = 217.65 km
# Iteración 20: Mejor costo hasta ahora = 212.85 km
# Iteración 30: Mejor costo hasta ahora = 210.32 km
# Iteración 40: Mejor costo hasta ahora = 208.25 km
# Iteración 50: Mejor costo hasta ahora = 208.25 km
# Iteración 60: Mejor costo hasta ahora = 202.41 km
# Iteración 70: Mejor costo hasta ahora = 202.41 km
# Iteración 80: Mejor costo hasta ahora = 202.41 km
# Iteración 90: Mejor costo hasta ahora = 202.41 km
# Iteración 100: Mejor costo hasta ahora = 201.25 km
# Resultados guardados en: resultados/18_100
#
#
# Archivo de inclusión generado: resultados/18_100/gams_18_100.inc
# Procesando archivo: redes/19_100.xlsx
# Generación 50: Mejor distancia = 746.59 km
# Generación 100: Mejor distancia = 746.59 km
# Generación 150: Mejor distancia = 746.59 km
# Generación 200: Mejor distancia = 746.59 km
# Generación 250: Mejor distancia = 746.59 km
# Generación 300: Mejor distancia = 746.59 km
# Generación 350: Mejor distancia = 746.59 km
# Generación 400: Mejor distancia = 709.62 km
# Generación 450: Mejor distancia = 699.45 km
# Generación 500: Mejor distancia = 699.45 km
# Iteración 10: Mejor costo hasta ahora = 206.75 km
# Iteración 20: Mejor costo hasta ahora = 200.57 km
# Iteración 30: Mejor costo hasta ahora = 196.62 km
# Iteración 40: Mejor costo hasta ahora = 196.62 km
# Iteración 50: Mejor costo hasta ahora = 196.62 km
# Iteración 60: Mejor costo hasta ahora = 194.59 km
# Iteración 70: Mejor costo hasta ahora = 194.59 km
# Iteración 80: Mejor costo hasta ahora = 194.59 km
# Iteración 90: Mejor costo hasta ahora = 193.80 km
# Iteración 100: Mejor costo hasta ahora = 193.80 km
# Resultados guardados en: resultados/19_100
#
#
# Archivo de inclusión generado: resultados/19_100/gams_19_100.inc
# Procesando archivo: redes/20_100.xlsx
# Generación 50: Mejor distancia = 781.78 km
# Generación 100: Mejor distancia = 748.95 km
# Generación 150: Mejor distancia = 738.25 km
# Generación 200: Mejor distancia = 719.41 km
# Generación 250: Mejor distancia = 719.41 km
# Generación 300: Mejor distancia = 719.41 km
# Generación 350: Mejor distancia = 719.41 km
# Generación 400: Mejor distancia = 719.41 km
# Generación 450: Mejor distancia = 719.41 km
# Generación 500: Mejor distancia = 719.41 km
# Iteración 10: Mejor costo hasta ahora = 215.84 km
# Iteración 20: Mejor costo hasta ahora = 215.84 km
# Iteración 30: Mejor costo hasta ahora = 213.32 km
# Iteración 40: Mejor costo hasta ahora = 213.32 km
# Iteración 50: Mejor costo hasta ahora = 213.32 km
# Iteración 60: Mejor costo hasta ahora = 213.32 km
# Iteración 70: Mejor costo hasta ahora = 213.32 km
# Iteración 80: Mejor costo hasta ahora = 213.32 km
# Iteración 90: Mejor costo hasta ahora = 213.32 km
# Iteración 100: Mejor costo hasta ahora = 213.32 km
# Resultados guardados en: resultados/20_100
#
#
# Archivo de inclusión generado: resultados/20_100/gams_20_100.inc
# Procesando archivo: redes/21_150.xlsx
# Generación 50: Mejor distancia = 1320.64 km
# Generación 100: Mejor distancia = 1233.16 km
# Generación 150: Mejor distancia = 1233.16 km
# Generación 200: Mejor distancia = 1233.16 km
# Generación 250: Mejor distancia = 1233.16 km
# Generación 300: Mejor distancia = 1233.16 km
# Generación 350: Mejor distancia = 1233.16 km
# Generación 400: Mejor distancia = 1233.16 km
# Generación 450: Mejor distancia = 1233.16 km
# Generación 500: Mejor distancia = 1233.16 km
# Iteración 10: Mejor costo hasta ahora = 304.36 km
# Iteración 20: Mejor costo hasta ahora = 291.93 km
# Iteración 30: Mejor costo hasta ahora = 281.25 km
# Iteración 40: Mejor costo hasta ahora = 281.25 km
# Iteración 50: Mejor costo hasta ahora = 281.25 km
# Iteración 60: Mejor costo hasta ahora = 281.25 km
# Iteración 70: Mejor costo hasta ahora = 281.25 km
# Iteración 80: Mejor costo hasta ahora = 281.25 km
# Iteración 90: Mejor costo hasta ahora = 277.88 km
# Iteración 100: Mejor costo hasta ahora = 277.88 km
# Resultados guardados en: resultados/21_150
#
#
# Archivo de inclusión generado: resultados/21_150/gams_21_150.inc
# Procesando archivo: redes/22_150.xlsx
# Generación 50: Mejor distancia = 1230.09 km
# Generación 100: Mejor distancia = 1229.94 km
# Generación 150: Mejor distancia = 1202.74 km
# Generación 200: Mejor distancia = 1202.74 km
# Generación 250: Mejor distancia = 1193.53 km
# Generación 300: Mejor distancia = 1193.53 km
# Generación 350: Mejor distancia = 1193.53 km
# Generación 400: Mejor distancia = 1193.53 km
# Generación 450: Mejor distancia = 1193.53 km
# Generación 500: Mejor distancia = 1193.53 km
# Iteración 10: Mejor costo hasta ahora = 292.94 km
# Iteración 20: Mejor costo hasta ahora = 288.50 km
# Iteración 30: Mejor costo hasta ahora = 279.37 km
# Iteración 40: Mejor costo hasta ahora = 279.37 km
# Iteración 50: Mejor costo hasta ahora = 279.37 km
# Iteración 60: Mejor costo hasta ahora = 279.37 km
# Iteración 70: Mejor costo hasta ahora = 279.37 km
# Iteración 80: Mejor costo hasta ahora = 279.06 km
# Iteración 90: Mejor costo hasta ahora = 279.06 km
# Iteración 100: Mejor costo hasta ahora = 277.38 km
# Resultados guardados en: resultados/22_150
#
#
# Archivo de inclusión generado: resultados/22_150/gams_22_150.inc
# Procesando archivo: redes/23_150.xlsx
# Generación 50: Mejor distancia = 1217.32 km
# Generación 100: Mejor distancia = 1199.11 km
# Generación 150: Mejor distancia = 1144.71 km
# Generación 200: Mejor distancia = 1144.71 km
# Generación 250: Mejor distancia = 1144.71 km
# Generación 300: Mejor distancia = 1144.71 km
# Generación 350: Mejor distancia = 1144.71 km
# Generación 400: Mejor distancia = 1144.71 km
# Generación 450: Mejor distancia = 1144.71 km
# Generación 500: Mejor distancia = 1144.71 km
# Iteración 10: Mejor costo hasta ahora = 267.96 km
# Iteración 20: Mejor costo hasta ahora = 267.96 km
# Iteración 30: Mejor costo hasta ahora = 267.96 km
# Iteración 40: Mejor costo hasta ahora = 267.96 km
# Iteración 50: Mejor costo hasta ahora = 267.96 km
# Iteración 60: Mejor costo hasta ahora = 267.96 km
# Iteración 70: Mejor costo hasta ahora = 265.03 km
# Iteración 80: Mejor costo hasta ahora = 265.03 km
# Iteración 90: Mejor costo hasta ahora = 265.03 km
# Iteración 100: Mejor costo hasta ahora = 265.03 km
# Resultados guardados en: resultados/23_150
#
#
# Archivo de inclusión generado: resultados/23_150/gams_23_150.inc
# Procesando archivo: redes/24_150.xlsx
# Generación 50: Mejor distancia = 1386.54 km
# Generación 100: Mejor distancia = 1363.42 km
# Generación 150: Mejor distancia = 1343.60 km
# Generación 200: Mejor distancia = 1343.60 km
# Generación 250: Mejor distancia = 1343.60 km
# Generación 300: Mejor distancia = 1343.60 km
# Generación 350: Mejor distancia = 1343.60 km
# Generación 400: Mejor distancia = 1335.83 km
# Generación 450: Mejor distancia = 1307.52 km
# Generación 500: Mejor distancia = 1307.52 km
# Iteración 10: Mejor costo hasta ahora = 308.60 km
# Iteración 20: Mejor costo hasta ahora = 286.62 km
# Iteración 30: Mejor costo hasta ahora = 286.62 km
# Iteración 40: Mejor costo hasta ahora = 284.14 km
# Iteración 50: Mejor costo hasta ahora = 284.14 km
# Iteración 60: Mejor costo hasta ahora = 284.14 km
# Iteración 70: Mejor costo hasta ahora = 284.14 km
# Iteración 80: Mejor costo hasta ahora = 284.14 km
# Iteración 90: Mejor costo hasta ahora = 284.14 km
# Iteración 100: Mejor costo hasta ahora = 284.14 km
# Resultados guardados en: resultados/24_150
#
#
# Archivo de inclusión generado: resultados/24_150/gams_24_150.inc
# Procesando archivo: redes/25_150.xlsx
# Generación 50: Mejor distancia = 1322.26 km
# Generación 100: Mejor distancia = 1228.21 km
# Generación 150: Mejor distancia = 1228.21 km
# Generación 200: Mejor distancia = 1228.21 km
# Generación 250: Mejor distancia = 1228.21 km
# Generación 300: Mejor distancia = 1228.21 km
# Generación 350: Mejor distancia = 1228.21 km
# Generación 400: Mejor distancia = 1228.21 km
# Generación 450: Mejor distancia = 1228.21 km
# Generación 500: Mejor distancia = 1228.21 km
# Iteración 10: Mejor costo hasta ahora = 271.82 km
# Iteración 20: Mejor costo hasta ahora = 264.67 km
# Iteración 30: Mejor costo hasta ahora = 255.91 km
# Iteración 40: Mejor costo hasta ahora = 253.15 km
# Iteración 50: Mejor costo hasta ahora = 253.15 km
# Iteración 60: Mejor costo hasta ahora = 253.15 km
# Iteración 70: Mejor costo hasta ahora = 252.91 km
# Iteración 80: Mejor costo hasta ahora = 248.80 km
# Iteración 90: Mejor costo hasta ahora = 248.80 km
# Iteración 100: Mejor costo hasta ahora = 248.80 km
# Resultados guardados en: resultados/25_150
#
#
# Archivo de inclusión generado: resultados/25_150/gams_25_150.inc
# Procesando archivo: redes/26_150.xlsx
# Generación 50: Mejor distancia = 1164.68 km
# Generación 100: Mejor distancia = 1149.16 km
# Generación 150: Mejor distancia = 1146.73 km
# Generación 200: Mejor distancia = 1138.21 km
# Generación 250: Mejor distancia = 1138.21 km
# Generación 300: Mejor distancia = 1124.09 km
# Generación 350: Mejor distancia = 1124.09 km
# Generación 400: Mejor distancia = 1124.09 km
# Generación 450: Mejor distancia = 1124.09 km
# Generación 500: Mejor distancia = 1124.09 km
# Iteración 10: Mejor costo hasta ahora = 262.57 km
# Iteración 20: Mejor costo hasta ahora = 251.73 km
# Iteración 30: Mejor costo hasta ahora = 246.58 km
# Iteración 40: Mejor costo hasta ahora = 246.58 km
# Iteración 50: Mejor costo hasta ahora = 246.58 km
# Iteración 60: Mejor costo hasta ahora = 246.58 km
# Iteración 70: Mejor costo hasta ahora = 246.58 km
# Iteración 80: Mejor costo hasta ahora = 246.58 km
# Iteración 90: Mejor costo hasta ahora = 246.58 km
# Iteración 100: Mejor costo hasta ahora = 246.58 km
# Resultados guardados en: resultados/26_150
#
#
# Archivo de inclusión generado: resultados/26_150/gams_26_150.inc
# Procesando archivo: redes/27_150.xlsx
# Generación 50: Mejor distancia = 1246.07 km
# Generación 100: Mejor distancia = 1245.83 km
# Generación 150: Mejor distancia = 1195.38 km
# Generación 200: Mejor distancia = 1195.38 km
# Generación 250: Mejor distancia = 1185.02 km
# Generación 300: Mejor distancia = 1185.02 km
# Generación 350: Mejor distancia = 1151.72 km
# Generación 400: Mejor distancia = 1143.57 km
# Generación 450: Mejor distancia = 1143.57 km
# Generación 500: Mejor distancia = 1143.57 km
# Iteración 10: Mejor costo hasta ahora = 276.94 km
# Iteración 20: Mejor costo hasta ahora = 264.31 km
# Iteración 30: Mejor costo hasta ahora = 264.31 km
# Iteración 40: Mejor costo hasta ahora = 263.80 km
# Iteración 50: Mejor costo hasta ahora = 263.80 km
# Iteración 60: Mejor costo hasta ahora = 263.80 km
# Iteración 70: Mejor costo hasta ahora = 258.57 km
# Iteración 80: Mejor costo hasta ahora = 258.57 km
# Iteración 90: Mejor costo hasta ahora = 258.57 km
# Iteración 100: Mejor costo hasta ahora = 258.57 km
# Resultados guardados en: resultados/27_150
#
#
# Archivo de inclusión generado: resultados/27_150/gams_27_150.inc
# Procesando archivo: redes/28_150.xlsx
# Generación 50: Mejor distancia = 1293.27 km
# Generación 100: Mejor distancia = 1266.62 km
# Generación 150: Mejor distancia = 1245.01 km
# Generación 200: Mejor distancia = 1202.99 km
# Generación 250: Mejor distancia = 1202.99 km
# Generación 300: Mejor distancia = 1202.99 km
# Generación 350: Mejor distancia = 1202.99 km
# Generación 400: Mejor distancia = 1202.99 km
# Generación 450: Mejor distancia = 1202.99 km
# Generación 500: Mejor distancia = 1190.54 km
# Iteración 10: Mejor costo hasta ahora = 303.85 km
# Iteración 20: Mejor costo hasta ahora = 296.52 km
# Iteración 30: Mejor costo hasta ahora = 290.85 km
# Iteración 40: Mejor costo hasta ahora = 290.85 km
# Iteración 50: Mejor costo hasta ahora = 290.85 km
# Iteración 60: Mejor costo hasta ahora = 290.85 km
# Iteración 70: Mejor costo hasta ahora = 290.85 km
# Iteración 80: Mejor costo hasta ahora = 290.85 km
# Iteración 90: Mejor costo hasta ahora = 290.85 km
# Iteración 100: Mejor costo hasta ahora = 290.85 km
# Resultados guardados en: resultados/28_150
#
#
# Archivo de inclusión generado: resultados/28_150/gams_28_150.inc
# Procesando archivo: redes/29_150.xlsx
# Generación 50: Mejor distancia = 1197.50 km
# Generación 100: Mejor distancia = 1125.81 km
# Generación 150: Mejor distancia = 1125.81 km
# Generación 200: Mejor distancia = 1125.81 km
# Generación 250: Mejor distancia = 1125.81 km
# Generación 300: Mejor distancia = 1125.81 km
# Generación 350: Mejor distancia = 1125.81 km
# Generación 400: Mejor distancia = 1125.81 km
# Generación 450: Mejor distancia = 1125.81 km
# Generación 500: Mejor distancia = 1125.81 km
# Iteración 10: Mejor costo hasta ahora = 233.76 km
# Iteración 20: Mejor costo hasta ahora = 222.06 km
# Iteración 30: Mejor costo hasta ahora = 222.06 km
# Iteración 40: Mejor costo hasta ahora = 222.06 km
# Iteración 50: Mejor costo hasta ahora = 218.97 km
# Iteración 60: Mejor costo hasta ahora = 218.97 km
# Iteración 70: Mejor costo hasta ahora = 218.97 km
# Iteración 80: Mejor costo hasta ahora = 218.97 km
# Iteración 90: Mejor costo hasta ahora = 218.97 km
# Iteración 100: Mejor costo hasta ahora = 218.97 km
# Resultados guardados en: resultados/29_150
#
#
# Archivo de inclusión generado: resultados/29_150/gams_29_150.inc
# Procesando archivo: redes/30_150.xlsx
# Generación 50: Mejor distancia = 1235.12 km
# Generación 100: Mejor distancia = 1222.80 km
# Generación 150: Mejor distancia = 1209.43 km
# Generación 200: Mejor distancia = 1209.43 km
# Generación 250: Mejor distancia = 1209.43 km
# Generación 300: Mejor distancia = 1209.43 km
# Generación 350: Mejor distancia = 1193.04 km
# Generación 400: Mejor distancia = 1192.48 km
# Generación 450: Mejor distancia = 1192.48 km
# Generación 500: Mejor distancia = 1192.48 km
# Iteración 10: Mejor costo hasta ahora = 268.29 km
# Iteración 20: Mejor costo hasta ahora = 255.48 km
# Iteración 30: Mejor costo hasta ahora = 250.17 km
# Iteración 40: Mejor costo hasta ahora = 250.17 km
# Iteración 50: Mejor costo hasta ahora = 250.17 km
# Iteración 60: Mejor costo hasta ahora = 250.17 km
# Iteración 70: Mejor costo hasta ahora = 250.17 km
# Iteración 80: Mejor costo hasta ahora = 247.44 km
# Iteración 90: Mejor costo hasta ahora = 247.44 km
# Iteración 100: Mejor costo hasta ahora = 247.44 km
# Resultados guardados en: resultados/30_150
#
#
# Archivo de inclusión generado: resultados/30_150/gams_30_150.inc
# Procesando archivo: redes/31_200.xlsx
# Generación 50: Mejor distancia = 1748.89 km
# Generación 100: Mejor distancia = 1655.21 km
# Generación 150: Mejor distancia = 1641.25 km
# Generación 200: Mejor distancia = 1641.25 km
# Generación 250: Mejor distancia = 1641.25 km
# Generación 300: Mejor distancia = 1641.25 km
# Generación 350: Mejor distancia = 1641.25 km
# Generación 400: Mejor distancia = 1641.25 km
# Generación 450: Mejor distancia = 1641.25 km
# Generación 500: Mejor distancia = 1641.25 km
# Iteración 10: Mejor costo hasta ahora = 348.08 km
# Iteración 20: Mejor costo hasta ahora = 332.66 km
# Iteración 30: Mejor costo hasta ahora = 327.65 km
# Iteración 40: Mejor costo hasta ahora = 327.65 km
# Iteración 50: Mejor costo hasta ahora = 327.65 km
# Iteración 60: Mejor costo hasta ahora = 325.94 km
# Iteración 70: Mejor costo hasta ahora = 325.94 km
# Iteración 80: Mejor costo hasta ahora = 325.94 km
# Iteración 90: Mejor costo hasta ahora = 325.94 km
# Iteración 100: Mejor costo hasta ahora = 321.25 km
# Resultados guardados en: resultados/31_200
#
#
# Archivo de inclusión generado: resultados/31_200/gams_31_200.inc
# Procesando archivo: redes/32_200.xlsx
# Generación 50: Mejor distancia = 1722.75 km
# Generación 100: Mejor distancia = 1687.82 km
# Generación 150: Mejor distancia = 1687.82 km
# Generación 200: Mejor distancia = 1687.82 km
# Generación 250: Mejor distancia = 1687.82 km
# Generación 300: Mejor distancia = 1687.82 km
# Generación 350: Mejor distancia = 1687.82 km
# Generación 400: Mejor distancia = 1681.74 km
# Generación 450: Mejor distancia = 1681.74 km
# Generación 500: Mejor distancia = 1681.74 km
# Iteración 10: Mejor costo hasta ahora = 355.41 km
# Iteración 20: Mejor costo hasta ahora = 337.18 km
# Iteración 30: Mejor costo hasta ahora = 337.18 km
# Iteración 40: Mejor costo hasta ahora = 333.90 km
# Iteración 50: Mejor costo hasta ahora = 333.90 km
# Iteración 60: Mejor costo hasta ahora = 329.42 km
# Iteración 70: Mejor costo hasta ahora = 329.42 km
# Iteración 80: Mejor costo hasta ahora = 329.42 km
# Iteración 90: Mejor costo hasta ahora = 329.42 km
# Iteración 100: Mejor costo hasta ahora = 329.42 km
# Resultados guardados en: resultados/32_200
#
#
# Archivo de inclusión generado: resultados/32_200/gams_32_200.inc
# Procesando archivo: redes/33_200.xlsx
# Generación 50: Mejor distancia = 1763.10 km
# Generación 100: Mejor distancia = 1754.83 km
# Generación 150: Mejor distancia = 1730.91 km
# Generación 200: Mejor distancia = 1730.91 km
# Generación 250: Mejor distancia = 1730.91 km
# Generación 300: Mejor distancia = 1730.91 km
# Generación 350: Mejor distancia = 1698.15 km
# Generación 400: Mejor distancia = 1698.15 km
# Generación 450: Mejor distancia = 1683.52 km
# Generación 500: Mejor distancia = 1683.52 km
# Iteración 10: Mejor costo hasta ahora = 348.40 km
# Iteración 20: Mejor costo hasta ahora = 342.66 km
# Iteración 30: Mejor costo hasta ahora = 337.69 km
# Iteración 40: Mejor costo hasta ahora = 337.69 km
# Iteración 50: Mejor costo hasta ahora = 327.13 km
# Iteración 60: Mejor costo hasta ahora = 327.13 km
# Iteración 70: Mejor costo hasta ahora = 326.30 km
# Iteración 80: Mejor costo hasta ahora = 326.30 km
# Iteración 90: Mejor costo hasta ahora = 326.30 km
# Iteración 100: Mejor costo hasta ahora = 326.30 km
# Resultados guardados en: resultados/33_200
#
#
# Archivo de inclusión generado: resultados/33_200/gams_33_200.inc
# Procesando archivo: redes/34_200.xlsx
# Generación 50: Mejor distancia = 1759.26 km
# Generación 100: Mejor distancia = 1750.60 km
# Generación 150: Mejor distancia = 1750.60 km
# Generación 200: Mejor distancia = 1750.60 km
# Generación 250: Mejor distancia = 1750.60 km
# Generación 300: Mejor distancia = 1750.60 km
# Generación 350: Mejor distancia = 1750.60 km
# Generación 400: Mejor distancia = 1732.69 km
# Generación 450: Mejor distancia = 1732.69 km
# Generación 500: Mejor distancia = 1732.69 km
# Iteración 10: Mejor costo hasta ahora = 340.61 km
# Iteración 20: Mejor costo hasta ahora = 328.08 km
# Iteración 30: Mejor costo hasta ahora = 325.80 km
# Iteración 40: Mejor costo hasta ahora = 319.47 km
# Iteración 50: Mejor costo hasta ahora = 319.47 km
# Iteración 60: Mejor costo hasta ahora = 319.47 km
# Iteración 70: Mejor costo hasta ahora = 319.19 km
# Iteración 80: Mejor costo hasta ahora = 316.43 km
# Iteración 90: Mejor costo hasta ahora = 316.43 km
# Iteración 100: Mejor costo hasta ahora = 316.43 km
# Resultados guardados en: resultados/34_200
#
#
# Archivo de inclusión generado: resultados/34_200/gams_34_200.inc
# Procesando archivo: redes/35_200.xlsx
# Generación 50: Mejor distancia = 1774.92 km
# Generación 100: Mejor distancia = 1764.93 km
# Generación 150: Mejor distancia = 1745.91 km
# Generación 200: Mejor distancia = 1728.38 km
# Generación 250: Mejor distancia = 1673.65 km
# Generación 300: Mejor distancia = 1673.65 km
# Generación 350: Mejor distancia = 1673.65 km
# Generación 400: Mejor distancia = 1673.65 km
# Generación 450: Mejor distancia = 1673.65 km
# Generación 500: Mejor distancia = 1673.65 km
# Iteración 10: Mejor costo hasta ahora = 344.42 km
# Iteración 20: Mejor costo hasta ahora = 336.47 km
# Iteración 30: Mejor costo hasta ahora = 325.66 km
# Iteración 40: Mejor costo hasta ahora = 325.66 km
# Iteración 50: Mejor costo hasta ahora = 325.66 km
# Iteración 60: Mejor costo hasta ahora = 325.66 km
# Iteración 70: Mejor costo hasta ahora = 325.66 km
# Iteración 80: Mejor costo hasta ahora = 325.66 km
# Iteración 90: Mejor costo hasta ahora = 325.66 km
# Iteración 100: Mejor costo hasta ahora = 325.66 km
# Resultados guardados en: resultados/35_200
#
#
# Archivo de inclusión generado: resultados/35_200/gams_35_200.inc
# Procesando archivo: redes/36_200.xlsx
# Generación 50: Mejor distancia = 1701.01 km
# Generación 100: Mejor distancia = 1701.01 km
# Generación 150: Mejor distancia = 1701.01 km
# Generación 200: Mejor distancia = 1701.01 km
# Generación 250: Mejor distancia = 1701.01 km
# Generación 300: Mejor distancia = 1701.01 km
# Generación 350: Mejor distancia = 1701.01 km
# Generación 400: Mejor distancia = 1701.01 km
# Generación 450: Mejor distancia = 1701.01 km
# Generación 500: Mejor distancia = 1701.01 km
# Iteración 10: Mejor costo hasta ahora = 340.67 km
# Iteración 20: Mejor costo hasta ahora = 338.27 km
# Iteración 30: Mejor costo hasta ahora = 331.49 km
# Iteración 40: Mejor costo hasta ahora = 331.49 km
# Iteración 50: Mejor costo hasta ahora = 331.49 km
# Iteración 60: Mejor costo hasta ahora = 327.92 km
# Iteración 70: Mejor costo hasta ahora = 327.92 km
# Iteración 80: Mejor costo hasta ahora = 327.92 km
# Iteración 90: Mejor costo hasta ahora = 325.34 km
# Iteración 100: Mejor costo hasta ahora = 325.34 km
# Resultados guardados en: resultados/36_200
#
#
# Archivo de inclusión generado: resultados/36_200/gams_36_200.inc
# Procesando archivo: redes/37_200.xlsx
# Generación 50: Mejor distancia = 1796.04 km
# Generación 100: Mejor distancia = 1692.45 km
# Generación 150: Mejor distancia = 1692.45 km
# Generación 200: Mejor distancia = 1692.45 km
# Generación 250: Mejor distancia = 1692.45 km
# Generación 300: Mejor distancia = 1692.45 km
# Generación 350: Mejor distancia = 1692.45 km
# Generación 400: Mejor distancia = 1683.98 km
# Generación 450: Mejor distancia = 1683.98 km
# Generación 500: Mejor distancia = 1683.98 km
# Iteración 10: Mejor costo hasta ahora = 316.28 km
# Iteración 20: Mejor costo hasta ahora = 305.37 km
# Iteración 30: Mejor costo hasta ahora = 303.75 km
# Iteración 40: Mejor costo hasta ahora = 303.75 km
# Iteración 50: Mejor costo hasta ahora = 303.68 km
# Iteración 60: Mejor costo hasta ahora = 300.67 km
# Iteración 70: Mejor costo hasta ahora = 297.89 km
# Iteración 80: Mejor costo hasta ahora = 297.89 km
# Iteración 90: Mejor costo hasta ahora = 297.89 km
# Iteración 100: Mejor costo hasta ahora = 297.89 km
# Resultados guardados en: resultados/37_200
#
#
# Archivo de inclusión generado: resultados/37_200/gams_37_200.inc
# Procesando archivo: redes/38_200.xlsx
# Generación 50: Mejor distancia = 1787.54 km
# Generación 100: Mejor distancia = 1678.82 km
# Generación 150: Mejor distancia = 1657.88 km
# Generación 200: Mejor distancia = 1657.88 km
# Generación 250: Mejor distancia = 1657.88 km
# Generación 300: Mejor distancia = 1657.88 km
# Generación 350: Mejor distancia = 1657.88 km
# Generación 400: Mejor distancia = 1657.88 km
# Generación 450: Mejor distancia = 1657.88 km
# Generación 500: Mejor distancia = 1657.88 km
# Iteración 10: Mejor costo hasta ahora = 343.62 km
# Iteración 20: Mejor costo hasta ahora = 326.46 km
# Iteración 30: Mejor costo hasta ahora = 326.46 km
# Iteración 40: Mejor costo hasta ahora = 326.46 km
# Iteración 50: Mejor costo hasta ahora = 326.46 km
# Iteración 60: Mejor costo hasta ahora = 326.26 km
# Iteración 70: Mejor costo hasta ahora = 326.26 km
# Iteración 80: Mejor costo hasta ahora = 325.60 km
# Iteración 90: Mejor costo hasta ahora = 325.60 km
# Iteración 100: Mejor costo hasta ahora = 325.60 km
# Resultados guardados en: resultados/38_200
#
#
# Archivo de inclusión generado: resultados/38_200/gams_38_200.inc
# Procesando archivo: redes/39_200.xlsx
# Generación 50: Mejor distancia = 1611.92 km
# Generación 100: Mejor distancia = 1611.92 km
# Generación 150: Mejor distancia = 1611.92 km
# Generación 200: Mejor distancia = 1611.92 km
# Generación 250: Mejor distancia = 1611.92 km
# Generación 300: Mejor distancia = 1611.92 km
# Generación 350: Mejor distancia = 1611.92 km
# Generación 400: Mejor distancia = 1611.92 km
# Generación 450: Mejor distancia = 1611.92 km
# Generación 500: Mejor distancia = 1611.92 km
# Iteración 10: Mejor costo hasta ahora = 320.20 km
# Iteración 20: Mejor costo hasta ahora = 308.17 km
# Iteración 30: Mejor costo hasta ahora = 296.25 km
# Iteración 40: Mejor costo hasta ahora = 296.25 km
# Iteración 50: Mejor costo hasta ahora = 296.25 km
# Iteración 60: Mejor costo hasta ahora = 296.25 km
# Iteración 70: Mejor costo hasta ahora = 296.25 km
# Iteración 80: Mejor costo hasta ahora = 295.35 km
# Iteración 90: Mejor costo hasta ahora = 295.35 km
# Iteración 100: Mejor costo hasta ahora = 295.35 km
# Resultados guardados en: resultados/39_200
#
#
# Archivo de inclusión generado: resultados/39_200/gams_39_200.inc
# Procesando archivo: redes/40_200.xlsx
# Generación 50: Mejor distancia = 1859.44 km
# Generación 100: Mejor distancia = 1800.02 km
# Generación 150: Mejor distancia = 1784.28 km
# Generación 200: Mejor distancia = 1772.60 km
# Generación 250: Mejor distancia = 1772.60 km
# Generación 300: Mejor distancia = 1772.60 km
# Generación 350: Mejor distancia = 1772.60 km
# Generación 400: Mejor distancia = 1769.05 km
# Generación 450: Mejor distancia = 1769.05 km
# Generación 500: Mejor distancia = 1769.05 km
# Iteración 10: Mejor costo hasta ahora = 351.91 km
# Iteración 20: Mejor costo hasta ahora = 333.73 km
# Iteración 30: Mejor costo hasta ahora = 324.43 km
# Iteración 40: Mejor costo hasta ahora = 323.95 km
# Iteración 50: Mejor costo hasta ahora = 321.61 km
# Iteración 60: Mejor costo hasta ahora = 321.61 km
# Iteración 70: Mejor costo hasta ahora = 321.61 km
# Iteración 80: Mejor costo hasta ahora = 321.61 km
# Iteración 90: Mejor costo hasta ahora = 321.61 km
# Iteración 100: Mejor costo hasta ahora = 321.61 km
# Resultados guardados en: resultados/40_200
#
#
# Archivo de inclusión generado: resultados/40_200/gams_40_200.inc
